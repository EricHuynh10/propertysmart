# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
import os
from io import StringIO
from constants import au_postcodes_df
from pydantic import BaseModel, ValidationError
from typing import Optional
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
school_types = ['primary', 'secondary']
states = list(au_postcodes_df['state'].unique())

# create an empty DataFrame to store the data
schools_with_score_df = pd.DataFrame(columns=['school', 'suburb', 'state', 'postcode', 'score', 'school_type'])

for school_type in school_types:
    for state in states:

        print(f"Start scraping  the webpage: {school_type} {state}")

        url = f'https://bettereducation.com.au/school/{school_type}/{state}/{state}_top_{school_type}_schools.aspx'
        response = requests.get(url)

        if response.status_code == 200:
            # Parse the HTML content
            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.find('table', {'id': 'ctl00_ContentPlaceHolder1_GridView1'})
            table_io = StringIO(str(table))

            # Convert the table to a DataFrame
            df = pd.read_html(table_io)[0]
            
            # Clean the DataFrame
            if state == 'VIC':
                df = df.rename(columns={'Postcode': 'postcode'})
                df['suburb'] = df['School'].str.split(',', expand=True).iloc[:, -3:-2]
            if state == 'ACT' or state == 'TAS':
                df[['suburb', 'state', 'postcode']] = df['School'].str.split(',', expand=True).iloc[:, -3:]
            if state == 'QLD':
                df['postcode'] = ''
                df["suburb"] = df['Locality']
            if state == 'SA' or state == 'NT' or state == 'NSW':
                df[['suburb', 'state', 'postcode']] = df['Locality'].str.split(',', expand=True).iloc[:, 0:3]
            if state == 'WA':
                if school_type == 'primary':
                    df[['suburb', 'state', 'postcode']] = df['Locality'].str.split(',', expand=True).iloc[:, 0:3]
                if school_type == 'secondary':
                    df = df.rename(columns={'Postcode': 'postcode'})
                    df['suburb'] = df['School'].str.split(',', expand=True).iloc[:, -3:-2]
            
            #handle special cases
            if school_type == 'primary':
                if state == 'NSW':
                    df.loc[df['School'] == 'Redlands,Cremorne,NSW,2090', ['suburb', 'state', 'postcode']] = ['Cremorne', 'NSW', '2090']
                if state == 'NT':
                    df.loc[df['Locality'] == 'Berrimah,NT,828', 'postcode'] = '0828'
            if school_type == 'secondary':
                if state == 'NSW':
                    df.loc[df['Locality'] == 'Surry Hills NSW 2010', ['suburb', 'state', 'postcode']] = ['Surry Hill', 'NSW', '2010']
                    df.loc[df['Locality'] == 'St Ives,St Ives,NSW,2075', ['suburb', 'state', 'postcode']] = ['St Ives', 'NSW', '2075']
                    df.loc[df['School'] == 'Redlands,Cremorne,NSW,2090', ['suburb', 'state', 'postcode']] = ['Cremorne', 'NSW', '2090']


            df['School'] = df['School'].str.split(',', expand=True).iloc[:, 0]
            df["state"] = state 
            df = df[['School', 'suburb', 'state', 'postcode', 'State Overall Score']]
            df = df.rename(columns={'School': 'school', 'State Overall Score': 'score'})
            df['educationLevel'] = school_type

            # assign the dataframe name df_school_type
            schools_with_score_df = pd.concat([schools_with_score_df, df], ignore_index=True)
            
            print(f"Successfully retrieved the webpage: {school_type} {state}")
        else:
            print(f"Failed to retrieve the webpage: status code {response.status_code}")
# Out:
# Start scraping  the webpage: primary NT
# Successfully retrieved the webpage: primary NT
# Start scraping  the webpage: primary NSW
# Successfully retrieved the webpage: primary NSW
# Start scraping  the webpage: primary ACT
# Successfully retrieved the webpage: primary ACT
# Start scraping  the webpage: primary VIC
# Successfully retrieved the webpage: primary VIC
# Start scraping  the webpage: primary QLD
# Successfully retrieved the webpage: primary QLD
# Start scraping  the webpage: primary SA
# Successfully retrieved the webpage: primary SA
# Start scraping  the webpage: primary WA
# Successfully retrieved the webpage: primary WA
# Start scraping  the webpage: primary TAS
# Successfully retrieved the webpage: primary TAS
# Start scraping  the webpage: secondary NT
# Successfully retrieved the webpage: secondary NT
# Start scraping  the webpage: secondary NSW
# Successfully retrieved the webpage: secondary NSW
# Start scraping  the webpage: secondary ACT
# Successfully retrieved the webpage: secondary ACT
# Start scraping  the webpage: secondary VIC
# Successfully retrieved the webpage: secondary VIC
# Start scraping  the webpage: secondary QLD
# Successfully retrieved the webpage: secondary QLD
# Start scraping  the webpage: secondary SA
# Successfully retrieved the webpage: secondary SA
# Start scraping  the webpage: secondary WA
# Successfully retrieved the webpage: secondary WA
# Start scraping  the webpage: secondary TAS
# Successfully retrieved the webpage: secondary TAS

# %%
schools_with_score_df
# Out:
#                            school           suburb state postcode score  \
# 0       Haileybury Rendall School         Berrimah    NT     0828   100
# 1     The Essington School Darwin       Nightcliff    NT     0810   100
# 2      Nhulunbuy Christian School        Nhulunbuy    NT     0880    99
# 3     Katherine School Of The Air        Katherine    NT     0850    99
# 4         Milkwood Steiner School         Berrimah    NT     0828    99
# ...                           ...              ...   ...      ...   ...
# 2247        Riverside High School        Riverside   TAS     7250    92
# 2248      St Brendan-Shaw College        Devonport   TAS     7310    91
# 2249                    Peregrine  Nicholls Rivule   TAS     7112    91
# 2250         Clarence High School        Bellerive   TAS     7018    90
# 2251         Rose Bay High School         Rose Bay   TAS     7015    90
#
#      school_type educationLevel
# 0            NaN        primary
# 1            NaN        primary
# 2            NaN        primary
# 3            NaN        primary
# 4            NaN        primary
# ...          ...            ...
# 2247         NaN      secondary
# 2248         NaN      secondary
# 2249         NaN      secondary
# 2250         NaN      secondary
# 2251         NaN      secondary
#
# [2252 rows x 7 columns]

# %%
# default header for the request
def header(url):
    headers = {
        'Accept': 'application/json',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8,zh-CN;q=0.7,zh;q=0.6',
        'Cache-Control': 'max-age=0',
        'Referer': url,
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    }
    return headers

# %%
class SchoolBase(BaseModel):
    school: str
    suburb: str
    state: str
    postcode: str
    schoolType: str
    educationLevel: str
    score: Optional[int] = None

# %%
def extract_school_from_suburb_profile():
    directory = os.path.join("D:\\aus_real_estate_data", 'suburb-profile')
    states = os.listdir(directory)
    url = 'http://localhost:8000/schools' # backend url to post data

    schools_df = pd.DataFrame(columns=['school', 'suburb', 'state', 'postcode', 'schoolType', 'educationLevel', 'score'])

    for state_code in states:
        d2 = os.path.join(directory, state_code)
        suburbs = os.listdir(d2)
        
        for suburb in suburbs:
            d3 = os.path.join(d2, suburb)
            json_files = os.listdir(d3)

            # Add missing import for json module

            for json_f in json_files:
                with open(os.path.join(d3, json_f)) as f:
                    suburb_profile = json.load(f)

                try:
                    schools = suburb_profile['props']['pageProps']['details'].get('schoolCatchment', {}).get('schools')
                    # Add a check for the existence of the 'schools' key before accessing it
                    if schools:
                        for school in schools:
                            school_data = SchoolBase(
                                school=school['name'],
                                suburb=" ".join(suburb.split('-')[0:-1]),
                                state=state_code,
                                postcode=str(suburb.split('-')[-1]),
                                schoolType=school['type'],
                                educationLevel=school['educationLevel'],
                                score=None
                            )

                            school_data = school_data.model_dump()
                            if school_data['educationLevel'] == 'combined':
                                school_data['educationLevel'] = 'primary'
                                schools_df = pd.concat([schools_df, pd.DataFrame([school_data])], ignore_index=True)
                                school_data['educationLevel'] = 'secondary'
                                schools_df = pd.concat([schools_df, pd.DataFrame([school_data])], ignore_index=True)
                            else:
                                schools_df = pd.concat([schools_df, pd.DataFrame([school_data])], ignore_index=True)
                except KeyError as e:
                    continue
        
    return schools_df

# %%
schools_df = extract_school_from_suburb_profile()

# %%
schools_df.sort_values(by=['postcode'], inplace=True)
schools_df
# Out:
#                                  school       suburb state postcode  \
# 3992                    Nemarluk School        ALAWA    NT     0810
# 4083          Nightcliff Primary School   NIGHTCLIFF    NT     0810
# 3991               Alawa Primary School        ALAWA    NT     0810
# 4088               The Essington School  RAPID CREEK    NT     0810
# 4087  St Paul's Catholic Primary School  RAPID CREEK    NT     0810
# ...                                 ...          ...   ...      ...
# 7539             Strahan Primary School      STRAHAN   TAS     7468
# 7582              Zeehan Primary School       ZEEHAN   TAS     7469
# 7497           Rosebery District School     ROSEBERY   TAS     7470
# 7495        St Joseph's Catholic School     ROSEBERY   TAS     7470
# 7496           Rosebery District School     ROSEBERY   TAS     7470
#
#       schoolType educationLevel score
# 3992  Government        primary  None
# 4083  Government        primary  None
# 3991  Government        primary  None
# 4088     Private        primary  None
# 4087    Catholic        primary  None
# ...          ...            ...   ...
# 7539  Government        primary  None
# 7582  Government        primary  None
# 7497  Government      secondary  None
# 7495    Catholic        primary  None
# 7496  Government        primary  None
#
# [12166 rows x 7 columns]

# %%
# Function to apply fuzzy matching
def get_best_match(row):
    name = str(row['suburb'])
    choices = au_postcodes_df[au_postcodes_df['state'] == row['state']]['suburb']
    best_match = process.extractOne(name, choices)
    if not best_match:
        return None
    return best_match[0]  # Returns the best match name

QLD_schools_with_score_df = schools_with_score_df[schools_with_score_df['postcode']==""]
QLD_schools_with_score_df['bestmatchsuburb'] = QLD_schools_with_score_df.apply(get_best_match, axis=1)
# Out:
# C:\Users\ericc\AppData\Local\Temp\ipykernel_15780\322312015.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QLD_schools_with_score_df['bestmatchsuburb'] = QLD_schools_with_score_df.apply(get_best_match, axis=1)

# %%
QLD_schools_with_score_df
# Out:
#                                       school           suburb state postcode  \
# 717             Sunnybank Hills State School  Sunnybank Hills   QLD
# 718             Citipointe Christian College        Carindale   QLD
# 719                   Ipswich Grammar School          Ipswich   QLD
# 720               St Peters Lutheran College    Indooroopilly   QLD
# 721           Anglican Church Grammar School    East Brisbane   QLD
# ...                                      ...              ...   ...      ...
# 2070                            Iona College           Lindum   QLD
# 2071  Lutheran Ormeau Rivers District School          Pimpama   QLD
# 2072                Wynnum State High School            Manly   QLD
# 2073           Ferny Grove State High School      Ferny Grove   QLD
# 2074             Trinity College (Gladstone)        Gladstone   QLD
#
#      score school_type educationLevel  bestmatchsuburb
# 717    100         NaN        primary  SUNNYBANK HILLS
# 718    100         NaN        primary        CARINDALE
# 719    100         NaN        primary          IPSWICH
# 720    100         NaN        primary    INDOOROOPILLY
# 721    100         NaN        primary    EAST BRISBANE
# ...    ...         ...            ...              ...
# 2070    90         NaN      secondary          WOONDUM
# 2071    90         NaN      secondary          PIMPAMA
# 2072    90         NaN      secondary            MANLY
# 2073    90         NaN      secondary      FERNY GROVE
# 2074    90         NaN      secondary        GLADSTONE
#
# [519 rows x 8 columns]

# %%
QLD_schools_with_score_df.drop(columns=['postcode', 'suburb'], inplace=True)
QLD_schools_with_score_df.rename(columns={'bestmatchsuburb': 'suburb'}, inplace=True)

QLD_schools_with_score_df
# Out:
# C:\Users\ericc\AppData\Local\Temp\ipykernel_15780\2734215646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QLD_schools_with_score_df.drop(columns=['postcode', 'suburb'], inplace=True)
# C:\Users\ericc\AppData\Local\Temp\ipykernel_15780\2734215646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QLD_schools_with_score_df.rename(columns={'bestmatchsuburb': 'suburb'}, inplace=True)
#                                       school state score school_type  \
# 717             Sunnybank Hills State School   QLD   100         NaN
# 718             Citipointe Christian College   QLD   100         NaN
# 719                   Ipswich Grammar School   QLD   100         NaN
# 720               St Peters Lutheran College   QLD   100         NaN
# 721           Anglican Church Grammar School   QLD   100         NaN
# ...                                      ...   ...   ...         ...
# 2070                            Iona College   QLD    90         NaN
# 2071  Lutheran Ormeau Rivers District School   QLD    90         NaN
# 2072                Wynnum State High School   QLD    90         NaN
# 2073           Ferny Grove State High School   QLD    90         NaN
# 2074             Trinity College (Gladstone)   QLD    90         NaN
#
#      educationLevel           suburb
# 717         primary  SUNNYBANK HILLS
# 718         primary        CARINDALE
# 719         primary          IPSWICH
# 720         primary    INDOOROOPILLY
# 721         primary    EAST BRISBANE
# ...             ...              ...
# 2070      secondary          WOONDUM
# 2071      secondary          PIMPAMA
# 2072      secondary            MANLY
# 2073      secondary      FERNY GROVE
# 2074      secondary        GLADSTONE
#
# [519 rows x 6 columns]

# %%
au_postcodes_df_copy = au_postcodes_df.copy()
#extract and show duplicates on state and suburb
au_postcodes_df_copy.drop_duplicates(subset=['state', 'suburb'], keep="first", inplace=True)

# %%
QLD_schools_with_score_df = QLD_schools_with_score_df.merge(au_postcodes_df_copy, on=['suburb', 'state'], suffixes=('_l', '_r'), how='left')
QLD_schools_with_score_df
# Out:
#                                      school state score school_type  \
# 0              Sunnybank Hills State School   QLD   100         NaN
# 1              Citipointe Christian College   QLD   100         NaN
# 2                    Ipswich Grammar School   QLD   100         NaN
# 3                St Peters Lutheran College   QLD   100         NaN
# 4            Anglican Church Grammar School   QLD   100         NaN
# ..                                      ...   ...   ...         ...
# 514                            Iona College   QLD    90         NaN
# 515  Lutheran Ormeau Rivers District School   QLD    90         NaN
# 516                Wynnum State High School   QLD    90         NaN
# 517           Ferny Grove State High School   QLD    90         NaN
# 518             Trinity College (Gladstone)   QLD    90         NaN
#
#     educationLevel           suburb postcode
# 0          primary  SUNNYBANK HILLS     4109
# 1          primary        CARINDALE     4152
# 2          primary          IPSWICH     4305
# 3          primary    INDOOROOPILLY     4068
# 4          primary    EAST BRISBANE     4169
# ..             ...              ...      ...
# 514      secondary          WOONDUM     4570
# 515      secondary          PIMPAMA     4209
# 516      secondary            MANLY     4179
# 517      secondary      FERNY GROVE     4055
# 518      secondary        GLADSTONE     4680
#
# [519 rows x 7 columns]

# %%
schools_with_score_df = schools_with_score_df[['school', 'suburb', 'state', 'postcode', 'score', 'school_type', 'educationLevel']]
QLD_schools_with_score_df = QLD_schools_with_score_df[['school', 'suburb', 'state', 'postcode', 'score', 'school_type', 'educationLevel']]

schools_with_score_df = pd.concat([schools_with_score_df[schools_with_score_df['state']!='QLD'], QLD_schools_with_score_df], ignore_index=True)
schools_with_score_df
# Out:
#                                       school       suburb state postcode  \
# 0                  Haileybury Rendall School     Berrimah    NT     0828
# 1                The Essington School Darwin   Nightcliff    NT     0810
# 2                 Nhulunbuy Christian School    Nhulunbuy    NT     0880
# 3                Katherine School Of The Air    Katherine    NT     0850
# 4                    Milkwood Steiner School     Berrimah    NT     0828
# ...                                      ...          ...   ...      ...
# 2247                            Iona College      WOONDUM   QLD     4570
# 2248  Lutheran Ormeau Rivers District School      PIMPAMA   QLD     4209
# 2249                Wynnum State High School        MANLY   QLD     4179
# 2250           Ferny Grove State High School  FERNY GROVE   QLD     4055
# 2251             Trinity College (Gladstone)    GLADSTONE   QLD     4680
#
#      score school_type educationLevel
# 0      100         NaN        primary
# 1      100         NaN        primary
# 2       99         NaN        primary
# 3       99         NaN        primary
# 4       99         NaN        primary
# ...    ...         ...            ...
# 2247    90         NaN      secondary
# 2248    90         NaN      secondary
# 2249    90         NaN      secondary
# 2250    90         NaN      secondary
# 2251    90         NaN      secondary
#
# [2252 rows x 7 columns]

# %%
# Preprocessing function for school names
def preprocess_school_names(name):
    # Implement your preprocessing logic here
    # For example, lowercasing, removing common suffixes/prefixes, etc.
    name.lower()
    name = name.replace('primary', '')
    name = name.replace('secondary', '')
    name = name.replace('school', '')
    name = name.replace('college', '')
    name = name.replace('public', '')
    name = name.replace('private', '')
    return name

# Apply preprocessing
schools_with_score_df['school_cleaned'] = schools_with_score_df['school'].apply(preprocess_school_names)
schools_df['school_cleaned'] = schools_df['school'].apply(preprocess_school_names)

# Function to apply fuzzy matching
def get_best_match(row):
    name = row['school_cleaned']
    choices = schools_df[(schools_df['postcode'] == str(row['postcode'])) & (df2['educationLevel'] == row['educationLevel'])]['school_cleaned']
    best_match = process.extractOne(name, choices, score_cutoff=80)
    if not best_match:
        return None
    return best_match[0]  # Returns the best match name

schools_with_score_df['BestMatchName'] = schools_with_score_df.apply(get_best_match, axis=1)

# %%
# add a column calculating similarity between school_cleaned and BestMatchName
schools_with_score_df['similarity'] = schools_with_score_df.apply(lambda row: fuzz.ratio(row['school_cleaned'], row['BestMatchName']), axis=1)
schools_with_score_df[(schools_with_score_df.duplicated(subset=['BestMatchName', 'postcode', 'educationLevel'], keep=False)) & (schools_with_score_df['state']=="NSW")].sort_values(by=['BestMatchName', 'postcode', 'educationLevel', 'similarity'], ascending=False)
# Out:
#                                                  school        suburb state  \
# 1193                           Sydney Girls High School   Surry Hills   NSW
# 1192                            Sydney Boys High School   Surry Hills   NSW
# 165            Sydney Distance Education Primary School   Surry Hills   NSW
# 36                                Sydney Grammar School  Darlinghurst   NSW
# 1221                         St George Christian School    Hurstville   NSW
# 1246                                    Danebank School    Hurstville   NSW
# 177                          North Sydney Public School      Waverton   NSW
# 79      SHORE - Sydney Church of England Grammar School  North Sydney   NSW
# 147                            Italian Bilingual School    Meadowbank   NSW
# 214                St Therese's Catholic Primary School     Denistone   NSW
# 221                        Epping Heights Public School        Epping   NSW
# 114   Our Lady Help of Christians Catholic Primary S...        Epping   NSW
# 35                      Coogee Boys' Preparatory School      Randwick   NSW
# 125                     Coogee Boys' Preparatory School      Randwick   NSW
#
#      postcode score school_type educationLevel  \
# 1193     2010   100         NaN      secondary
# 1192     2010   100         NaN      secondary
# 165      2010    97         NaN        primary
# 36       2010   100         NaN        primary
# 1221     2220    98         NaN      secondary
# 1246     2220    97         NaN      secondary
# 177      2060    96         NaN        primary
# 79       2060    99         NaN        primary
# 147      2114    98         NaN        primary
# 214      2114   PNO         NaN        primary
# 221      2121   PNO         NaN        primary
# 114      2121    98         NaN        primary
# 35       2031    98         NaN        primary
# 125      2031    98         NaN        primary
#
#                                          school_cleaned  \
# 1193                           Sydney Girls High School
# 1192                            Sydney Boys High School
# 165            Sydney Distance Education Primary School
# 36                                Sydney Grammar School
# 1221                         St George Christian School
# 1246                                    Danebank School
# 177                          North Sydney Public School
# 79      SHORE - Sydney Church of England Grammar School
# 147                            Italian Bilingual School
# 214                St Therese's Catholic Primary School
# 221                        Epping Heights Public School
# 114   Our Lady Help of Christians Catholic Primary S...
# 35                      Coogee Boys' Preparatory School
# 125                     Coogee Boys' Preparatory School
#
#                                  BestMatchName  similarity
# 1193                  Sydney Girls High School         100
# 1192                  Sydney Girls High School          85
# 165   Sydney Distance Education Primary School         100
# 36    Sydney Distance Education Primary School          59
# 1221                St George Christian School         100
# 1246                St George Christian School          49
# 177                 North Sydney Public School         100
# 79                  North Sydney Public School          47
# 147                   Italian Bilingual School         100
# 214                   Italian Bilingual School          47
# 221               Epping Heights Public School         100
# 114               Epping Heights Public School          43
# 35             Coogee Boys' Preparatory School         100
# 125            Coogee Boys' Preparatory School         100

# %%
schools_with_score_df = schools_with_score_df.sort_values(by=['BestMatchName', 'postcode', 'educationLevel', 'similarity'], ascending=False)
schools_with_score_df.drop_duplicates(subset=['BestMatchName', 'postcode', 'educationLevel'], keep='first', inplace=True)
schools_with_score_df = schools_with_score_df[schools_with_score_df['BestMatchName'].notnull()]
schools_with_score_df = schools_with_score_df[schools_with_score_df['similarity'] >= 80]
#concate 3 columns bestmatchname, postcode, educationLevel to create a unique key
schools_with_score_df['key'] = schools_with_score_df['BestMatchName'].astype(str) + schools_with_score_df['postcode'].astype(str) + schools_with_score_df['educationLevel'].astype(str)

schools_with_score_df
# Out:
#                          school        suburb state postcode score  \
# 1021      Yuluma Primary School       Innaloo    WA     6018    94
# 1934  Yorkeys Knob State School  YORKEYS KNOB   QLD     4878    94
# 1029      Yokine Primary School        Yokine    WA     6060    94
# 475       Yinnar Primary School          None   VIC     3869    95
# 1518    Yesodei Hatorah College        Elwood   VIC     3184    92
# ...                         ...           ...   ...      ...   ...
# 1206                Abbotsleigh     Wahroonga   NSW     2076    99
# 38                  Abbotsleigh     Wahroonga   NSW     2076   100
# 493   Abbotsford Primary School          None   VIC     3067    95
# 2107       A B Paterson College       ARUNDEL   QLD     4214    99
# 1757       A B Paterson College       ARUNDEL   QLD     4214    99
#
#      school_type educationLevel             school_cleaned  \
# 1021         NaN        primary      Yuluma Primary School
# 1934         NaN        primary  Yorkeys Knob State School
# 1029         NaN        primary      Yokine Primary School
# 475          NaN        primary      Yinnar Primary School
# 1518         NaN      secondary    Yesodei Hatorah College
# ...          ...            ...                        ...
# 1206         NaN      secondary                Abbotsleigh
# 38           NaN        primary                Abbotsleigh
# 493          NaN        primary  Abbotsford Primary School
# 2107         NaN      secondary       A B Paterson College
# 1757         NaN        primary       A B Paterson College
#
#                   BestMatchName  similarity  \
# 1021      Yuluma Primary School         100
# 1934  Yorkeys Knob State School         100
# 1029      Yokine Primary School         100
# 475       Yinnar Primary School         100
# 1518    Yesodei HaTorah College          96
# ...                         ...         ...
# 1206                Abbotsleigh         100
# 38                  Abbotsleigh         100
# 493   Abbotsford Primary School         100
# 2107       A B Paterson College         100
# 1757       A B Paterson College         100
#
#                                        key
# 1021      Yuluma Primary School6018primary
# 1934  Yorkeys Knob State School4878primary
# 1029      Yokine Primary School6060primary
# 475       Yinnar Primary School3869primary
# 1518  Yesodei HaTorah College3184secondary
# ...                                    ...
# 1206              Abbotsleigh2076secondary
# 38                  Abbotsleigh2076primary
# 493   Abbotsford Primary School3067primary
# 2107     A B Paterson College4214secondary
# 1757       A B Paterson College4214primary
#
# [2036 rows x 11 columns]

# %%
schools_df['key'] = schools_df['school_cleaned'].astype(str) + schools_df['postcode'].astype(str) + schools_df['educationLevel'].astype(str)
schools_df
# Out:
#                                  school       suburb state postcode  \
# 3992                    Nemarluk School        ALAWA    NT     0810
# 4083          Nightcliff Primary School   NIGHTCLIFF    NT     0810
# 3991               Alawa Primary School        ALAWA    NT     0810
# 4088               The Essington School  RAPID CREEK    NT     0810
# 4087  St Paul's Catholic Primary School  RAPID CREEK    NT     0810
# ...                                 ...          ...   ...      ...
# 7539             Strahan Primary School      STRAHAN   TAS     7468
# 7582              Zeehan Primary School       ZEEHAN   TAS     7469
# 7497           Rosebery District School     ROSEBERY   TAS     7470
# 7495        St Joseph's Catholic School     ROSEBERY   TAS     7470
# 7496           Rosebery District School     ROSEBERY   TAS     7470
#
#       schoolType educationLevel score                     school_cleaned  \
# 3992  Government        primary  None                    Nemarluk School
# 4083  Government        primary  None          Nightcliff Primary School
# 3991  Government        primary  None               Alawa Primary School
# 4088     Private        primary  None               The Essington School
# 4087    Catholic        primary  None  St Paul's Catholic Primary School
# ...          ...            ...   ...                                ...
# 7539  Government        primary  None             Strahan Primary School
# 7582  Government        primary  None              Zeehan Primary School
# 7497  Government      secondary  None           Rosebery District School
# 7495    Catholic        primary  None        St Joseph's Catholic School
# 7496  Government        primary  None           Rosebery District School
#
#                                                key
# 3992                    Nemarluk School0810primary
# 4083          Nightcliff Primary School0810primary
# 3991               Alawa Primary School0810primary
# 4088               The Essington School0810primary
# 4087  St Paul's Catholic Primary School0810primary
# ...                                            ...
# 7539             Strahan Primary School7468primary
# 7582              Zeehan Primary School7469primary
# 7497         Rosebery District School7470secondary
# 7495        St Joseph's Catholic School7470primary
# 7496           Rosebery District School7470primary
#
# [12166 rows x 9 columns]

# %%
final = pd.merge(schools_df, schools_with_score_df, how='left', left_on=['key'], right_on=['key'], suffixes=('_l', '_r'))
final[final['school_cleaned_r'].notnull()].drop_duplicates(subset=['school_cleaned_l', 'postcode_l', 'educationLevel_l'], keep='first')
# Out:
#                                 school_l     suburb_l state_l postcode_l  \
# 1              Nightcliff Primary School   NIGHTCLIFF      NT       0810
# 2                   Alawa Primary School        ALAWA      NT       0810
# 3                   The Essington School  RAPID CREEK      NT       0810
# 4      St Paul's Catholic Primary School  RAPID CREEK      NT       0810
# 8                 Jingili Primary School      JINGILI      NT       0810
# ...                                  ...          ...     ...        ...
# 12114         Leighland Christian School   ULVERSTONE     TAS       7315
# 12123               Riana Primary School        RIANA     TAS       7316
# 12129            Marist Regional College       BURNIE     TAS       7320
# 12130       Stella Maris Catholic School       BURNIE     TAS       7320
# 12144        St Brigid's Catholic School      WYNYARD     TAS       7325
#
#        schoolType educationLevel_l score_l                   school_cleaned_l  \
# 1      Government          primary    None          Nightcliff Primary School
# 2      Government          primary    None               Alawa Primary School
# 3         Private          primary    None               The Essington School
# 4        Catholic          primary    None  St Paul's Catholic Primary School
# 8      Government          primary    None             Jingili Primary School
# ...           ...              ...     ...                                ...
# 12114     Private        secondary    None         Leighland Christian School
# 12123  Government          primary    None               Riana Primary School
# 12129    Catholic        secondary    None            Marist Regional College
# 12130    Catholic          primary    None       Stella Maris Catholic School
# 12144    Catholic          primary    None        St Brigid's Catholic School
#
#                                                 key  \
# 1              Nightcliff Primary School0810primary
# 2                   Alawa Primary School0810primary
# 3                   The Essington School0810primary
# 4      St Paul's Catholic Primary School0810primary
# 8                 Jingili Primary School0810primary
# ...                                             ...
# 12114       Leighland Christian School7315secondary
# 12123               Riana Primary School7316primary
# 12129          Marist Regional College7320secondary
# 12130       Stella Maris Catholic School7320primary
# 12144        St Brigid's Catholic School7325primary
#
#                                    school_r    suburb_r state_r postcode_r  \
# 1                 Nightcliff Primary School  Nightcliff      NT       0810
# 2                      Alawa Primary School       Alawa      NT       0810
# 3               The Essington School Darwin  Nightcliff      NT       0810
# 4         St Paul's Catholic Primary School  Nightcliff      NT       0810
# 8                    Jingili Primary School     Jingili      NT       0810
# ...                                     ...         ...     ...        ...
# 12114            Leighland Christian School  Ulverstone     TAS       7315
# 12123                  Riana Primary School       Riana     TAS       7316
# 12129               Marist Regional College      Burnie     TAS       7320
# 12130  Stella Maris Catholic Primary School      Burnie     TAS       7320
# 12144           St Brigid's Catholic School     Wynyard     TAS       7325
#
#       score_r school_type educationLevel_r  \
# 1          98         NaN          primary
# 2          96         NaN          primary
# 3         100         NaN          primary
# 4          97         NaN          primary
# 8          94         NaN          primary
# ...       ...         ...              ...
# 12114      96         NaN        secondary
# 12123      97         NaN          primary
# 12129      93         NaN        secondary
# 12130      94         NaN          primary
# 12144      92         NaN          primary
#
#                            school_cleaned_r  \
# 1                 Nightcliff Primary School
# 2                      Alawa Primary School
# 3               The Essington School Darwin
# 4         St Paul's Catholic Primary School
# 8                    Jingili Primary School
# ...                                     ...
# 12114            Leighland Christian School
# 12123                  Riana Primary School
# 12129               Marist Regional College
# 12130  Stella Maris Catholic Primary School
# 12144           St Brigid's Catholic School
#
#                            BestMatchName  similarity
# 1              Nightcliff Primary School       100.0
# 2                   Alawa Primary School       100.0
# 3                   The Essington School        85.0
# 4      St Paul's Catholic Primary School       100.0
# 8                 Jingili Primary School       100.0
# ...                                  ...         ...
# 12114         Leighland Christian School       100.0
# 12123               Riana Primary School       100.0
# 12129            Marist Regional College       100.0
# 12130       Stella Maris Catholic School        88.0
# 12144        St Brigid's Catholic School       100.0
#
# [2036 rows x 19 columns]

# %%
final = final[['school_l', 'suburb_l', 'state_l', 'postcode_l', 'score_r', 'schoolType', 'educationLevel_l']]
final.rename(columns={'school_l': 'school', 'suburb_l': 'suburb', 'state_l': 'state', 'postcode_l': 'postcode', 'score_r': 'score', 'educationLevel_l': 'educationLevel'}, inplace=True)

# %%
final.drop_duplicates(subset=['school', 'postcode', 'educationLevel'], keep='first', inplace=True)

# %%
final
# Out:
#                                   school       suburb state postcode score  \
# 0                        Nemarluk School        ALAWA    NT     0810   NaN
# 1              Nightcliff Primary School   NIGHTCLIFF    NT     0810    98
# 2                   Alawa Primary School        ALAWA    NT     0810    96
# 3                   The Essington School  RAPID CREEK    NT     0810   100
# 4      St Paul's Catholic Primary School  RAPID CREEK    NT     0810    97
# ...                                  ...          ...   ...      ...   ...
# 12161             Strahan Primary School      STRAHAN   TAS     7468   NaN
# 12162              Zeehan Primary School       ZEEHAN   TAS     7469   NaN
# 12163           Rosebery District School     ROSEBERY   TAS     7470   NaN
# 12164        St Joseph's Catholic School     ROSEBERY   TAS     7470   NaN
# 12165           Rosebery District School     ROSEBERY   TAS     7470   NaN
#
#        schoolType educationLevel
# 0      Government        primary
# 1      Government        primary
# 2      Government        primary
# 3         Private        primary
# 4        Catholic        primary
# ...           ...            ...
# 12161  Government        primary
# 12162  Government        primary
# 12163  Government      secondary
# 12164    Catholic        primary
# 12165  Government        primary
#
# [12148 rows x 7 columns]

# %%
final.to_csv('D:\\aus_real_estate_data\schools\schools.csv', index=False)
