# %%
import os
import json
import pandas as pd
import numpy as np
import requests
from constants import data_folder, backend_url

from suburb_remoteness import suburb_remoteness_df

# %%
directory = os.path.join(data_folder, "suburb-profile") # directory where suburb profile data is stored
url = f'{backend_url}/suburb/' # url to post data to db
states = os.listdir(directory)

suburb_data_df = pd.DataFrame()

for state_code in states:
    d2 = os.path.join(directory, state_code)
    suburbs = os.listdir(d2)

    for suburb in suburbs:
        d3 = os.path.join(d2, suburb)
        json_files = os.listdir(d3)
        suburb, postcode = suburb[:-5], suburb[-4:]

        # Add missing import for json module
        for json_f in json_files:
            with open(os.path.join(d3, json_f)) as f:
                suburb_profile = json.load(f)
            
            try:
                mkt_insights = suburb_profile['props']['pageProps']['details']['marketInsights']
            except:
                continue
            
            for value in mkt_insights:
                temp = {}
                temp['state'] = state_code
                temp['suburb'] = suburb
                temp['postcode'] = postcode
                temp['beds'] = value['beds']
                temp['propertyType'] = value['propertyType']
                temp['medianPrice'] = value['medianPrice'] if value['medianPrice'] > 0 else np.nan
                temp['medianRent'] = value['medianRentPrice'] if value['medianRentPrice'] > 0 else np.nan
                temp['avgDaysOnMarket'] = value['avgDaysOnMarket'] if value['avgDaysOnMarket'] > 0 else np.nan
                temp['soldThisYear'] = value['nrSoldThisYear']
                temp['entryLevelPrice'] = value['entryLevelPrice'] if value['entryLevelPrice'] > 0 else np.nan
                temp['luxuryLevelPrice'] = value['luxuryLevelPrice'] if value['luxuryLevelPrice'] > 0 else np.nan
                temp['annualGrowth'] = np.nan
                for i in value['salesGrowthList']:
                    if i['year'] == '2023':
                        temp['annualGrowth'] = i['annualGrowth'] if i['annualGrowth'] > 0 else np.nan
                
                suburb_data_df = pd.concat([suburb_data_df, pd.DataFrame([temp])], ignore_index=True)
        
        print('Finished processing suburb:', suburb, 'postcode:', postcode, 'state:', state_code)

suburb_data_df['rentalYield'] = (suburb_data_df['medianRent'] * 52) / suburb_data_df['medianPrice']
suburb_data_df['totalYield'] = suburb_data_df['rentalYield'] + suburb_data_df['annualGrowth']
suburb_data_df = pd.merge(suburb_data_df, suburb_remoteness_df, on=['postcode', 'state'], how='left')

#suburb_data_df.to_csv('suburb_data.csv', index=False)
suburb_data_json = json.loads(suburb_data_df.to_json(orient='records'))
# Out:
# Finished processing suburb: ACTON postcode: 2601 state: ACT
# Finished processing suburb: AINSLIE postcode: 2602 state: ACT
# Finished processing suburb: AMAROO postcode: 2914 state: ACT
# Finished processing suburb: ARANDA postcode: 2614 state: ACT
# Finished processing suburb: BANKS postcode: 2906 state: ACT
# Finished processing suburb: BARTON postcode: 2600 state: ACT
# Finished processing suburb: BELCONNEN postcode: 2617 state: ACT
# Finished processing suburb: BONNER postcode: 2914 state: ACT
# Finished processing suburb: BONYTHON postcode: 2905 state: ACT
# Finished processing suburb: BRADDON postcode: 2612 state: ACT
# Finished processing suburb: BRUCE postcode: 2617 state: ACT
# Finished processing suburb: CALWELL postcode: 2905 state: ACT
# Finished processing suburb: CAMPBELL postcode: 2612 state: ACT
# Finished processing suburb: CANBERRA postcode: 2600 state: ACT
# Finished processing suburb: CASEY postcode: 2913 state: ACT
# Finished processing suburb: CHAPMAN postcode: 2611 state: ACT
# Finished processing suburb: CHARNWOOD postcode: 2615 state: ACT
# Finished processing suburb: CHIFLEY postcode: 2606 state: ACT
# Finished processing suburb: CHISHOLM postcode: 2905 state: ACT
# Finished processing suburb: CITY postcode: 2601 state: ACT
# Finished processing suburb: CONDER postcode: 2906 state: ACT
# Finished processing suburb: COOK postcode: 2614 state: ACT
# Finished processing suburb: COOMBS postcode: 2611 state: ACT
# Finished processing suburb: CRACE postcode: 2911 state: ACT
# Finished processing suburb: CURTIN postcode: 2605 state: ACT
# Finished processing suburb: DEAKIN postcode: 2600 state: ACT
# Finished processing suburb: DENMAN PROSPECT postcode: 2611 state: ACT
# Finished processing suburb: DICKSON postcode: 2602 state: ACT
# Finished processing suburb: DOWNER postcode: 2602 state: ACT
# Finished processing suburb: DUFFY postcode: 2611 state: ACT
# Finished processing suburb: DUNLOP postcode: 2615 state: ACT
# Finished processing suburb: EVATT postcode: 2617 state: ACT
# Finished processing suburb: FADDEN postcode: 2904 state: ACT
# Finished processing suburb: FARRER postcode: 2607 state: ACT
# Finished processing suburb: FISHER postcode: 2611 state: ACT
# Finished processing suburb: FLOREY postcode: 2615 state: ACT
# Finished processing suburb: FLYNN postcode: 2615 state: ACT
# Finished processing suburb: FORDE postcode: 2914 state: ACT
# Finished processing suburb: FORREST postcode: 2603 state: ACT
# Finished processing suburb: FRANKLIN postcode: 2913 state: ACT
# Finished processing suburb: FRASER postcode: 2615 state: ACT
# Finished processing suburb: GARRAN postcode: 2605 state: ACT
# Finished processing suburb: GILMORE postcode: 2905 state: ACT
# Finished processing suburb: GIRALANG postcode: 2617 state: ACT
# Finished processing suburb: GLENEAGLES postcode: 2902 state: ACT
# Finished processing suburb: GORDON postcode: 2906 state: ACT
# Finished processing suburb: GOWRIE postcode: 2904 state: ACT
# Finished processing suburb: GREENWAY postcode: 2900 state: ACT
# Finished processing suburb: GRIFFITH postcode: 2603 state: ACT
# Finished processing suburb: GUNGAHLIN postcode: 2912 state: ACT
# Finished processing suburb: HACKETT postcode: 2602 state: ACT
# Finished processing suburb: HALL postcode: 2618 state: ACT
# Finished processing suburb: HARRISON postcode: 2914 state: ACT
# Finished processing suburb: HAWKER postcode: 2614 state: ACT
# Finished processing suburb: HIGGINS postcode: 2615 state: ACT
# Finished processing suburb: HOLDER postcode: 2611 state: ACT
# Finished processing suburb: HOLT postcode: 2615 state: ACT
# Finished processing suburb: HUGHES postcode: 2605 state: ACT
# Finished processing suburb: ISAACS postcode: 2607 state: ACT
# Finished processing suburb: ISABELLA PLAINS postcode: 2905 state: ACT
# Finished processing suburb: JACKA postcode: 2914 state: ACT
# Finished processing suburb: KALEEN postcode: 2617 state: ACT
# Finished processing suburb: KAMBAH postcode: 2902 state: ACT
# Finished processing suburb: KINGSTON postcode: 2604 state: ACT
# Finished processing suburb: LATHAM postcode: 2615 state: ACT
# Finished processing suburb: LAWSON postcode: 2617 state: ACT
# Finished processing suburb: LYNEHAM postcode: 2602 state: ACT
# Finished processing suburb: LYONS postcode: 2606 state: ACT
# Finished processing suburb: MACARTHUR postcode: 2904 state: ACT
# Finished processing suburb: MACGREGOR postcode: 2615 state: ACT
# Finished processing suburb: MACNAMARA postcode: 2615 state: ACT
# Finished processing suburb: MACQUARIE postcode: 2614 state: ACT
# Finished processing suburb: MANUKA postcode: 2603 state: ACT
# Finished processing suburb: MAWSON postcode: 2607 state: ACT
# Finished processing suburb: MCKELLAR postcode: 2617 state: ACT
# Finished processing suburb: MELBA postcode: 2615 state: ACT
# Finished processing suburb: MONASH postcode: 2904 state: ACT
# Finished processing suburb: MONCRIEFF postcode: 2914 state: ACT
# Finished processing suburb: NARRABUNDAH postcode: 2604 state: ACT
# Finished processing suburb: NGUNNAWAL postcode: 2913 state: ACT
# Finished processing suburb: NICHOLLS postcode: 2913 state: ACT
# Finished processing suburb: NORTH LYNEHAM postcode: 2602 state: ACT
# Finished processing suburb: O'CONNOR postcode: 2602 state: ACT
# Finished processing suburb: O'MALLEY postcode: 2606 state: ACT
# Finished processing suburb: OAKS ESTATE postcode: 2620 state: ACT
# Finished processing suburb: OXLEY postcode: 2903 state: ACT
# Finished processing suburb: PAGE postcode: 2614 state: ACT
# Finished processing suburb: PALMERSTON postcode: 2913 state: ACT
# Finished processing suburb: PARKES postcode: 2600 state: ACT
# Finished processing suburb: PEARCE postcode: 2607 state: ACT
# Finished processing suburb: PHILLIP postcode: 2606 state: ACT
# Finished processing suburb: RED HILL postcode: 2603 state: ACT
# Finished processing suburb: REID postcode: 2612 state: ACT
# Finished processing suburb: RICHARDSON postcode: 2905 state: ACT
# Finished processing suburb: RIVETT postcode: 2611 state: ACT
# Finished processing suburb: SCULLIN postcode: 2614 state: ACT
# Finished processing suburb: SPENCE postcode: 2615 state: ACT
# Finished processing suburb: STIRLING postcode: 2611 state: ACT
# Finished processing suburb: STRATHNAIRN postcode: 2615 state: ACT
# Finished processing suburb: SWINGER HILL postcode: 2606 state: ACT
# Finished processing suburb: SYMONSTON postcode: 2609 state: ACT
# Finished processing suburb: TAYLOR postcode: 2913 state: ACT
# Finished processing suburb: THEODORE postcode: 2905 state: ACT
# Finished processing suburb: THROSBY postcode: 2914 state: ACT
# Finished processing suburb: TORRENS postcode: 2607 state: ACT
# Finished processing suburb: TURNER postcode: 2612 state: ACT
# Finished processing suburb: URIARRA VILLAGE postcode: 2611 state: ACT
# Finished processing suburb: WANNIASSA postcode: 2903 state: ACT
# Finished processing suburb: WARAMANGA postcode: 2611 state: ACT
# Finished processing suburb: WATSON postcode: 2602 state: ACT
# Finished processing suburb: WEETANGERA postcode: 2614 state: ACT
# Finished processing suburb: WESTON postcode: 2611 state: ACT
# Finished processing suburb: WHITLAM postcode: 2611 state: ACT
# Finished processing suburb: WODEN postcode: 2606 state: ACT
# Finished processing suburb: WRIGHT postcode: 2611 state: ACT
# Finished processing suburb: YARRALUMLA postcode: 2600 state: ACT
# Finished processing suburb: ABBOTSBURY postcode: 2176 state: NSW
# Finished processing suburb: ABBOTSFORD postcode: 2046 state: NSW
# Finished processing suburb: ABERCROMBIE postcode: 2795 state: NSW
# Finished processing suburb: ABERDARE postcode: 2325 state: NSW
# Finished processing suburb: ABERDEEN postcode: 2336 state: NSW
# Finished processing suburb: ABERGLASSLYN postcode: 2320 state: NSW
# Finished processing suburb: ABERMAIN postcode: 2326 state: NSW
# Finished processing suburb: ABERNETHY postcode: 2325 state: NSW
# Finished processing suburb: ACACIA GARDENS postcode: 2763 state: NSW
# Finished processing suburb: ADAMINABY postcode: 2629 state: NSW
# Finished processing suburb: ADAMSTOWN HEIGHTS postcode: 2289 state: NSW
# Finished processing suburb: ADAMSTOWN postcode: 2289 state: NSW
# Finished processing suburb: ADELONG postcode: 2729 state: NSW
# Finished processing suburb: AGNES BANKS postcode: 2753 state: NSW
# Finished processing suburb: AIRDS postcode: 2560 state: NSW
# Finished processing suburb: AKOLELE postcode: 2546 state: NSW
# Finished processing suburb: ALBION PARK RAIL postcode: 2527 state: NSW
# Finished processing suburb: ALBION PARK postcode: 2527 state: NSW
# Finished processing suburb: ALBURY postcode: 2640 state: NSW
# Finished processing suburb: ALDAVILLA postcode: 2440 state: NSW
# Finished processing suburb: ALECTOWN postcode: 2870 state: NSW
# Finished processing suburb: ALEXANDRIA postcode: 2015 state: NSW
# Finished processing suburb: ALFORDS POINT postcode: 2234 state: NSW
# Finished processing suburb: ALFREDTOWN postcode: 2650 state: NSW
# Finished processing suburb: ALLAMBIE HEIGHTS postcode: 2100 state: NSW
# Finished processing suburb: ALLAMBIE postcode: 2100 state: NSW
# Finished processing suburb: ALLAWAH postcode: 2218 state: NSW
# Finished processing suburb: ALLGOMERA postcode: 2441 state: NSW
# Finished processing suburb: ALLWORTH postcode: 2425 state: NSW
# Finished processing suburb: ALLYNBROOK postcode: 2311 state: NSW
# Finished processing suburb: ALPINE postcode: 2575 state: NSW
# Finished processing suburb: ALSTONVALE postcode: 2477 state: NSW
# Finished processing suburb: ALSTONVILLE postcode: 2477 state: NSW
# Finished processing suburb: ALUMY CREEK postcode: 2460 state: NSW
# Finished processing suburb: AMBARVALE postcode: 2560 state: NSW
# Finished processing suburb: ANAMBAH postcode: 2320 state: NSW
# Finished processing suburb: ANDO postcode: 2631 state: NSW
# Finished processing suburb: ANGLEDALE postcode: 2550 state: NSW
# Finished processing suburb: ANGLERS REACH postcode: 2629 state: NSW
# Finished processing suburb: ANGOURIE postcode: 2464 state: NSW
# Finished processing suburb: ANGUS postcode: 2765 state: NSW
# Finished processing suburb: ANNA BAY postcode: 2316 state: NSW
# Finished processing suburb: ANNANDALE postcode: 2038 state: NSW
# Finished processing suburb: ANNANGROVE postcode: 2156 state: NSW
# Finished processing suburb: APPIN postcode: 2560 state: NSW
# Finished processing suburb: ARAKOON postcode: 2431 state: NSW
# Finished processing suburb: ARALUEN postcode: 2622 state: NSW
# Finished processing suburb: ARCADIA VALE postcode: 2283 state: NSW
# Finished processing suburb: ARCADIA postcode: 2159 state: NSW
# Finished processing suburb: ARDING postcode: 2358 state: NSW
# Finished processing suburb: ARDLETHAN postcode: 2665 state: NSW
# Finished processing suburb: ARGENTON postcode: 2284 state: NSW
# Finished processing suburb: ARGENTS HILL postcode: 2449 state: NSW
# Finished processing suburb: ARIAH PARK postcode: 2665 state: NSW
# Finished processing suburb: ARMATREE postcode: 2828 state: NSW
# Finished processing suburb: ARMIDALE postcode: 2350 state: NSW
# Finished processing suburb: ARNCLIFFE postcode: 2205 state: NSW
# Finished processing suburb: ARRAWARRA HEADLAND postcode: 2456 state: NSW
# Finished processing suburb: ARRAWARRA postcode: 2456 state: NSW
# Finished processing suburb: ARTARMON postcode: 2064 state: NSW
# Finished processing suburb: ARTHURVILLE postcode: 2820 state: NSW
# Finished processing suburb: ASHBURY postcode: 2193 state: NSW
# Finished processing suburb: ASHBY HEIGHTS postcode: 2463 state: NSW
# Finished processing suburb: ASHBY postcode: 2463 state: NSW
# Finished processing suburb: ASHCROFT postcode: 2168 state: NSW
# Finished processing suburb: ASHFIELD postcode: 2131 state: NSW
# Finished processing suburb: ASHFORD postcode: 2361 state: NSW
# Finished processing suburb: ASHLEY postcode: 2400 state: NSW
# Finished processing suburb: ASHMONT postcode: 2650 state: NSW
# Finished processing suburb: ASHTONFIELD postcode: 2323 state: NSW
# Finished processing suburb: ASQUITH postcode: 2077 state: NSW
# Finished processing suburb: ATTUNGA postcode: 2345 state: NSW
# Finished processing suburb: AUBURN postcode: 2144 state: NSW
# Finished processing suburb: AUSTINMER postcode: 2515 state: NSW
# Finished processing suburb: AUSTRAL postcode: 2179 state: NSW
# Finished processing suburb: AVALON BEACH postcode: 2107 state: NSW
# Finished processing suburb: AVOCA BEACH postcode: 2251 state: NSW
# Finished processing suburb: AVOCA postcode: 2577 state: NSW
# Finished processing suburb: AVONDALE postcode: 2530 state: NSW
# Finished processing suburb: AVONSIDE postcode: 2628 state: NSW
# Finished processing suburb: AWABA postcode: 2283 state: NSW
# Finished processing suburb: AYLMERTON postcode: 2575 state: NSW
# Finished processing suburb: BAAN BAA postcode: 2390 state: NSW
# Finished processing suburb: BACK FOREST postcode: 2535 state: NSW
# Finished processing suburb: BACKMEDE postcode: 2470 state: NSW
# Finished processing suburb: BADGERYS CREEK postcode: 2555 state: NSW
# Finished processing suburb: BAGNOO postcode: 2446 state: NSW
# Finished processing suburb: BAGOTVILLE postcode: 2477 state: NSW
# Finished processing suburb: BALACLAVA postcode: 2575 state: NSW
# Finished processing suburb: BALALA postcode: 2358 state: NSW
# Finished processing suburb: BALCOLYN postcode: 2264 state: NSW
# Finished processing suburb: BALD HILLS postcode: 2549 state: NSW
# Finished processing suburb: BALGOWLAH HEIGHTS postcode: 2093 state: NSW
# Finished processing suburb: BALGOWLAH postcode: 2093 state: NSW
# Finished processing suburb: BALGOWNIE postcode: 2519 state: NSW
# Finished processing suburb: BALLDALE postcode: 2646 state: NSW
# Finished processing suburb: BALLIMORE postcode: 2830 state: NSW
# Finished processing suburb: BALLINA postcode: 2478 state: NSW
# Finished processing suburb: BALMAIN EAST postcode: 2041 state: NSW
# Finished processing suburb: BALMAIN postcode: 2041 state: NSW
# Finished processing suburb: BALMORAL VILLAGE postcode: 2571 state: NSW
# Finished processing suburb: BALMORAL postcode: 2283 state: NSW
# Finished processing suburb: BALMORAL postcode: 2571 state: NSW
# Finished processing suburb: BALRANALD postcode: 2715 state: NSW
# Finished processing suburb: BANDON GROVE postcode: 2420 state: NSW
# Finished processing suburb: BANGALEE postcode: 2541 state: NSW
# Finished processing suburb: BANGALOW postcode: 2479 state: NSW
# Finished processing suburb: BANGOR postcode: 2234 state: NSW
# Finished processing suburb: BANKSIA postcode: 2216 state: NSW
# Finished processing suburb: BANKSMEADOW postcode: 2019 state: NSW
# Finished processing suburb: BANKSTOWN postcode: 2200 state: NSW
# Finished processing suburb: BANORA POINT postcode: 2486 state: NSW
# Finished processing suburb: BANYABBA postcode: 2460 state: NSW
# Finished processing suburb: BAR BEACH postcode: 2300 state: NSW
# Finished processing suburb: BAR POINT postcode: 2083 state: NSW
# Finished processing suburb: BARADINE postcode: 2396 state: NSW
# Finished processing suburb: BARANGAROO postcode: 2000 state: NSW
# Finished processing suburb: BARCOONGERE postcode: 2460 state: NSW
# Finished processing suburb: BARDEN RIDGE postcode: 2234 state: NSW
# Finished processing suburb: BARDIA postcode: 2565 state: NSW
# Finished processing suburb: BARDWELL PARK postcode: 2207 state: NSW
# Finished processing suburb: BARDWELL VALLEY postcode: 2207 state: NSW
# Finished processing suburb: BARELLAN postcode: 2665 state: NSW
# Finished processing suburb: BARGO postcode: 2574 state: NSW
# Finished processing suburb: BARHAM postcode: 2732 state: NSW
# Finished processing suburb: BARKERS VALE postcode: 2474 state: NSW
# Finished processing suburb: BARMEDMAN postcode: 2668 state: NSW
# Finished processing suburb: BARNEYS REEF postcode: 2852 state: NSW
# Finished processing suburb: BARNSLEY postcode: 2278 state: NSW
# Finished processing suburb: BAROOGA postcode: 3644 state: NSW
# Finished processing suburb: BARRABA postcode: 2347 state: NSW
# Finished processing suburb: BARRACK HEIGHTS postcode: 2528 state: NSW
# Finished processing suburb: BARRACK POINT postcode: 2528 state: NSW
# Finished processing suburb: BARRAGANYATTI postcode: 2441 state: NSW
# Finished processing suburb: BARRAGGA BAY postcode: 2546 state: NSW
# Finished processing suburb: BARRENGARRY postcode: 2577 state: NSW
# Finished processing suburb: BARRINGTON postcode: 2422 state: NSW
# Finished processing suburb: BARRY postcode: 2799 state: NSW
# Finished processing suburb: BASIN VIEW postcode: 2540 state: NSW
# Finished processing suburb: BASS HILL postcode: 2197 state: NSW
# Finished processing suburb: BATAR CREEK postcode: 2439 state: NSW
# Finished processing suburb: BATEAU BAY postcode: 2261 state: NSW
# Finished processing suburb: BATEHAVEN postcode: 2536 state: NSW
# Finished processing suburb: BATEMANS BAY postcode: 2536 state: NSW
# Finished processing suburb: BATHURST postcode: 2795 state: NSW
# Finished processing suburb: BATLOW postcode: 2730 state: NSW
# Finished processing suburb: BAULKHAM HILLS postcode: 2153 state: NSW
# Finished processing suburb: BAWLEY POINT postcode: 2539 state: NSW
# Finished processing suburb: BAYVIEW postcode: 2104 state: NSW
# Finished processing suburb: BEACON HILL postcode: 2100 state: NSW
# Finished processing suburb: BEACONSFIELD postcode: 2015 state: NSW
# Finished processing suburb: BEAUMONT HILLS postcode: 2155 state: NSW
# Finished processing suburb: BEAUMONT postcode: 2577 state: NSW
# Finished processing suburb: BECKOM postcode: 2665 state: NSW
# Finished processing suburb: BEDGERABONG postcode: 2871 state: NSW
# Finished processing suburb: BEDGEREBONG postcode: 2871 state: NSW
# Finished processing suburb: BEECHWOOD postcode: 2446 state: NSW
# Finished processing suburb: BEECROFT postcode: 2119 state: NSW
# Finished processing suburb: BEELBANGERA postcode: 2680 state: NSW
# Finished processing suburb: BEEMUNNEL postcode: 2824 state: NSW
# Finished processing suburb: BEGA postcode: 2550 state: NSW
# Finished processing suburb: BELFIELD postcode: 2191 state: NSW
# Finished processing suburb: BELFORD postcode: 2335 state: NSW
# Finished processing suburb: BELIMBLA PARK postcode: 2570 state: NSW
# Finished processing suburb: BELL postcode: 2786 state: NSW
# Finished processing suburb: BELLA VISTA postcode: 2153 state: NSW
# Finished processing suburb: BELLAMBI postcode: 2518 state: NSW
# Finished processing suburb: BELLATA postcode: 2397 state: NSW
# Finished processing suburb: BELLAWONGARAH postcode: 2535 state: NSW
# Finished processing suburb: BELLBIRD HEIGHTS postcode: 2325 state: NSW
# Finished processing suburb: BELLBIRD postcode: 2325 state: NSW
# Finished processing suburb: BELLBROOK postcode: 2440 state: NSW
# Finished processing suburb: BELLEVUE HILL postcode: 2023 state: NSW
# Finished processing suburb: BELLIMBOPINNI postcode: 2440 state: NSW
# Finished processing suburb: BELLINGEN postcode: 2454 state: NSW
# Finished processing suburb: BELLMOUNT FOREST postcode: 2581 state: NSW
# Finished processing suburb: BELMONT NORTH postcode: 2280 state: NSW
# Finished processing suburb: BELMONT SOUTH postcode: 2280 state: NSW
# Finished processing suburb: BELMONT postcode: 2280 state: NSW
# Finished processing suburb: BELMORE RIVER postcode: 2440 state: NSW
# Finished processing suburb: BELMORE postcode: 2192 state: NSW
# Finished processing suburb: BELROSE postcode: 2085 state: NSW
# Finished processing suburb: BEMBOKA postcode: 2550 state: NSW
# Finished processing suburb: BEN BULLEN postcode: 2790 state: NSW
# Finished processing suburb: BEN LOMOND postcode: 2365 state: NSW
# Finished processing suburb: BENDALONG postcode: 2539 state: NSW
# Finished processing suburb: BENDEMEER postcode: 2355 state: NSW
# Finished processing suburb: BENDICK MURRELL postcode: 2803 state: NSW
# Finished processing suburb: BENDOLBA postcode: 2420 state: NSW
# Finished processing suburb: BENSVILLE postcode: 2251 state: NSW
# Finished processing suburb: BERALA postcode: 2141 state: NSW
# Finished processing suburb: BERAMBING postcode: 2758 state: NSW
# Finished processing suburb: BERESFIELD postcode: 2322 state: NSW
# Finished processing suburb: BERGALIA postcode: 2537 state: NSW
# Finished processing suburb: BERKELEY VALE postcode: 2261 state: NSW
# Finished processing suburb: BERKELEY postcode: 2506 state: NSW
# Finished processing suburb: BERKSHIRE PARK postcode: 2765 state: NSW
# Finished processing suburb: BERMAGUI postcode: 2546 state: NSW
# Finished processing suburb: BEROWRA HEIGHTS postcode: 2082 state: NSW
# Finished processing suburb: BEROWRA WATERS postcode: 2082 state: NSW
# Finished processing suburb: BEROWRA postcode: 2081 state: NSW
# Finished processing suburb: BERRAMBOOL postcode: 2548 state: NSW
# Finished processing suburb: BERRARA postcode: 2540 state: NSW
# Finished processing suburb: BERRIDALE postcode: 2628 state: NSW
# Finished processing suburb: BERRIGAN postcode: 2712 state: NSW
# Finished processing suburb: BERRILEE postcode: 2159 state: NSW
# Finished processing suburb: BERRIMA postcode: 2577 state: NSW
# Finished processing suburb: BERRINGER LAKE postcode: 2539 state: NSW
# Finished processing suburb: BERRY MOUNTAIN postcode: 2535 state: NSW
# Finished processing suburb: BERRY PARK postcode: 2321 state: NSW
# Finished processing suburb: BERRY postcode: 2535 state: NSW
# Finished processing suburb: BETHUNGRA postcode: 2590 state: NSW
# Finished processing suburb: BEVENDALE postcode: 2581 state: NSW
# Finished processing suburb: BEVERLEY PARK postcode: 2217 state: NSW
# Finished processing suburb: BEVERLY HILLS postcode: 2209 state: NSW
# Finished processing suburb: BEWONG postcode: 2540 state: NSW
# Finished processing suburb: BEXHILL postcode: 2480 state: NSW
# Finished processing suburb: BEXLEY NORTH postcode: 2207 state: NSW
# Finished processing suburb: BEXLEY postcode: 2207 state: NSW
# Finished processing suburb: BIBBENLUKE postcode: 2632 state: NSW
# Finished processing suburb: BIDWILL postcode: 2770 state: NSW
# Finished processing suburb: BIG HILL postcode: 2579 state: NSW
# Finished processing suburb: BIGGA postcode: 2583 state: NSW
# Finished processing suburb: BILAMBIL HEIGHTS postcode: 2486 state: NSW
# Finished processing suburb: BILAMBIL postcode: 2486 state: NSW
# Finished processing suburb: BILBUL postcode: 2680 state: NSW
# Finished processing suburb: BILGOLA BEACH postcode: 2107 state: NSW
# Finished processing suburb: BILGOLA PLATEAU postcode: 2107 state: NSW
# Finished processing suburb: BILGOLA postcode: 2107 state: NSW
# Finished processing suburb: BILLIMARI postcode: 2804 state: NSW
# Finished processing suburb: BILLINUDGEL postcode: 2483 state: NSW
# Finished processing suburb: BILLYS CREEK postcode: 2453 state: NSW
# Finished processing suburb: BILLYWILLINGA postcode: 2795 state: NSW
# Finished processing suburb: BILPIN postcode: 2758 state: NSW
# Finished processing suburb: BIMBI postcode: 2810 state: NSW
# Finished processing suburb: BIMBIMBIE postcode: 2536 state: NSW
# Finished processing suburb: BINALONG postcode: 2584 state: NSW
# Finished processing suburb: BINDA postcode: 2583 state: NSW
# Finished processing suburb: BINGARA postcode: 2404 state: NSW
# Finished processing suburb: BINGIE postcode: 2537 state: NSW
# Finished processing suburb: BINIGUY postcode: 2399 state: NSW
# Finished processing suburb: BINJURA postcode: 2630 state: NSW
# Finished processing suburb: BINNA BURRA postcode: 2479 state: NSW
# Finished processing suburb: BINNAWAY postcode: 2395 state: NSW
# Finished processing suburb: BIRCHGROVE postcode: 2041 state: NSW
# Finished processing suburb: BIRMINGHAM GARDENS postcode: 2287 state: NSW
# Finished processing suburb: BIRRIWA postcode: 2844 state: NSW
# Finished processing suburb: BIRRONG postcode: 2143 state: NSW
# Finished processing suburb: BISHOPS BRIDGE postcode: 2326 state: NSW
# Finished processing suburb: BLACK HEAD postcode: 2430 state: NSW
# Finished processing suburb: BLACK HILL postcode: 2322 state: NSW
# Finished processing suburb: BLACK MOUNTAIN postcode: 2365 state: NSW
# Finished processing suburb: BLACK RANGE postcode: 2550 state: NSW
# Finished processing suburb: BLACK SPRINGS postcode: 2787 state: NSW
# Finished processing suburb: BLACKALLS PARK postcode: 2283 state: NSW
# Finished processing suburb: BLACKBUTT postcode: 2529 state: NSW
# Finished processing suburb: BLACKETT postcode: 2770 state: NSW
# Finished processing suburb: BLACKHEATH postcode: 2785 state: NSW
# Finished processing suburb: BLACKMANS POINT postcode: 2444 state: NSW
# Finished processing suburb: BLACKSMITHS postcode: 2281 state: NSW
# Finished processing suburb: BLACKTOWN postcode: 2148 state: NSW
# Finished processing suburb: BLACKVILLE postcode: 2343 state: NSW
# Finished processing suburb: BLACKWALL postcode: 2256 state: NSW
# Finished processing suburb: BLAIR ATHOL postcode: 2560 state: NSW
# Finished processing suburb: BLAIRMOUNT postcode: 2559 state: NSW
# Finished processing suburb: BLAKEBROOK postcode: 2480 state: NSW
# Finished processing suburb: BLAKEHURST postcode: 2221 state: NSW
# Finished processing suburb: BLANDFORD postcode: 2338 state: NSW
# Finished processing suburb: BLAXLAND postcode: 2774 state: NSW
# Finished processing suburb: BLAXLANDS CREEK postcode: 2460 state: NSW
# Finished processing suburb: BLAXLANDS RIDGE postcode: 2758 state: NSW
# Finished processing suburb: BLAYNEY postcode: 2799 state: NSW
# Finished processing suburb: BLIGH PARK postcode: 2756 state: NSW
# Finished processing suburb: BLIGHTY postcode: 2713 state: NSW
# Finished processing suburb: BLUE BAY postcode: 2261 state: NSW
# Finished processing suburb: BLUE HAVEN postcode: 2262 state: NSW
# Finished processing suburb: BLUE KNOB postcode: 2480 state: NSW
# Finished processing suburb: BLUEYS BEACH postcode: 2428 state: NSW
# Finished processing suburb: BOAMBEE EAST postcode: 2452 state: NSW
# Finished processing suburb: BOAMBEE postcode: 2450 state: NSW
# Finished processing suburb: BOAT HARBOUR postcode: 2316 state: NSW
# Finished processing suburb: BOAT HARBOUR postcode: 2480 state: NSW
# Finished processing suburb: BOBIN postcode: 2429 state: NSW
# Finished processing suburb: BOBS CREEK postcode: 2439 state: NSW
# Finished processing suburb: BOBS FARM postcode: 2316 state: NSW
# Finished processing suburb: BODALLA postcode: 2545 state: NSW
# Finished processing suburb: BODANGORA postcode: 2820 state: NSW
# Finished processing suburb: BOEILL CREEK postcode: 2739 state: NSW
# Finished processing suburb: BOGAN GATE postcode: 2876 state: NSW
# Finished processing suburb: BOGANGAR postcode: 2488 state: NSW
# Finished processing suburb: BOGGABILLA postcode: 2409 state: NSW
# Finished processing suburb: BOGGABRI postcode: 2382 state: NSW
# Finished processing suburb: BOHENA CREEK postcode: 2390 state: NSW
# Finished processing suburb: BOHNOCK postcode: 2430 state: NSW
# Finished processing suburb: BOLTON POINT postcode: 2283 state: NSW
# Finished processing suburb: BOLWARRA HEIGHTS postcode: 2320 state: NSW
# Finished processing suburb: BOLWARRA postcode: 2320 state: NSW
# Finished processing suburb: BOMADERRY postcode: 2541 state: NSW
# Finished processing suburb: BOMBAH POINT postcode: 2423 state: NSW
# Finished processing suburb: BOMBALA postcode: 2632 state: NSW
# Finished processing suburb: BOMBAY postcode: 2622 state: NSW
# Finished processing suburb: BOMBIRA postcode: 2850 state: NSW
# Finished processing suburb: BOMBO postcode: 2533 state: NSW
# Finished processing suburb: BONALBO postcode: 2469 state: NSW
# Finished processing suburb: BONDI BEACH postcode: 2026 state: NSW
# Finished processing suburb: BONDI JUNCTION postcode: 2022 state: NSW
# Finished processing suburb: BONDI postcode: 2026 state: NSW
# Finished processing suburb: BONNELLS BAY postcode: 2264 state: NSW
# Finished processing suburb: BONNET BAY postcode: 2226 state: NSW
# Finished processing suburb: BONNY HILLS postcode: 2445 state: NSW
# Finished processing suburb: BONNYRIGG HEIGHTS postcode: 2177 state: NSW
# Finished processing suburb: BONNYRIGG postcode: 2177 state: NSW
# Finished processing suburb: BONSHAW postcode: 2361 state: NSW
# Finished processing suburb: BONVILLE postcode: 2450 state: NSW
# Finished processing suburb: BOOKER BAY postcode: 2257 state: NSW
# Finished processing suburb: BOOKHAM postcode: 2582 state: NSW
# Finished processing suburb: BOOLAMBAYTE postcode: 2423 state: NSW
# Finished processing suburb: BOOLAROO postcode: 2284 state: NSW
# Finished processing suburb: BOOMERANG BEACH postcode: 2428 state: NSW
# Finished processing suburb: BOOMI postcode: 2405 state: NSW
# Finished processing suburb: BOORAGUL postcode: 2284 state: NSW
# Finished processing suburb: BOORAL postcode: 2425 state: NSW
# Finished processing suburb: BOORGANNA postcode: 2429 state: NSW
# Finished processing suburb: BOOROOMA postcode: 2650 state: NSW
# Finished processing suburb: BOOROWA postcode: 2586 state: NSW
# Finished processing suburb: BOOYONG postcode: 2480 state: NSW
# Finished processing suburb: BORA RIDGE postcode: 2471 state: NSW
# Finished processing suburb: BOREE CREEK postcode: 2652 state: NSW
# Finished processing suburb: BORENORE postcode: 2800 state: NSW
# Finished processing suburb: BORO postcode: 2622 state: NSW
# Finished processing suburb: BOSSLEY PARK postcode: 2176 state: NSW
# Finished processing suburb: BOSTOBRICK postcode: 2453 state: NSW
# Finished processing suburb: BOTANY postcode: 2019 state: NSW
# Finished processing suburb: BOURKE postcode: 2840 state: NSW
# Finished processing suburb: BOURKELANDS postcode: 2650 state: NSW
# Finished processing suburb: BOURNDA postcode: 2548 state: NSW
# Finished processing suburb: BOW BOWING postcode: 2566 state: NSW
# Finished processing suburb: BOWAN PARK postcode: 2864 state: NSW
# Finished processing suburb: BOWEN MOUNTAIN postcode: 2753 state: NSW
# Finished processing suburb: BOWENFELS postcode: 2790 state: NSW
# Finished processing suburb: BOWMAN FARM postcode: 2422 state: NSW
# Finished processing suburb: BOWNA postcode: 2644 state: NSW
# Finished processing suburb: BOWNING postcode: 2582 state: NSW
# Finished processing suburb: BOWRAL postcode: 2576 state: NSW
# Finished processing suburb: BOWRAVILLE postcode: 2449 state: NSW
# Finished processing suburb: BOX HILL postcode: 2765 state: NSW
# Finished processing suburb: BOYDTOWN postcode: 2551 state: NSW
# Finished processing suburb: BRADBURY postcode: 2560 state: NSW
# Finished processing suburb: BRAEFIELD postcode: 2339 state: NSW
# Finished processing suburb: BRAEMAR postcode: 2575 state: NSW
# Finished processing suburb: BRAIDWOOD postcode: 2622 state: NSW
# Finished processing suburb: BRANDY HILL postcode: 2324 state: NSW
# Finished processing suburb: BRANXTON postcode: 2335 state: NSW
# Finished processing suburb: BRAUNSTONE postcode: 2460 state: NSW
# Finished processing suburb: BRAY PARK postcode: 2484 state: NSW
# Finished processing suburb: BRAYS CREEK postcode: 2484 state: NSW
# Finished processing suburb: BRAYTON postcode: 2579 state: NSW
# Finished processing suburb: BREADALBANE postcode: 2581 state: NSW
# Finished processing suburb: BREAKFAST POINT postcode: 2137 state: NSW
# Finished processing suburb: BREDBO postcode: 2626 state: NSW
# Finished processing suburb: BREEZA postcode: 2381 state: NSW
# Finished processing suburb: BREWARRINA postcode: 2839 state: NSW
# Finished processing suburb: BREWONGLE postcode: 2795 state: NSW
# Finished processing suburb: BRIBBAREE postcode: 2594 state: NSW
# Finished processing suburb: BRIERFIELD postcode: 2454 state: NSW
# Finished processing suburb: BRIGHTON-LE-SANDS postcode: 2216 state: NSW
# Finished processing suburb: BRIGHTWATERS postcode: 2264 state: NSW
# Finished processing suburb: BRIMBIN postcode: 2430 state: NSW
# Finished processing suburb: BRINGELLY postcode: 2556 state: NSW
# Finished processing suburb: BROADMEADOW postcode: 2292 state: NSW
# Finished processing suburb: BROADWATER postcode: 2472 state: NSW
# Finished processing suburb: BROADWATER postcode: 2549 state: NSW
# Finished processing suburb: BROADWAY postcode: 2007 state: NSW
# Finished processing suburb: BROCKLEHURST postcode: 2830 state: NSW
# Finished processing suburb: BROCKLESBY postcode: 2642 state: NSW
# Finished processing suburb: BROGERS CREEK postcode: 2535 state: NSW
# Finished processing suburb: BROGO postcode: 2550 state: NSW
# Finished processing suburb: BROKE postcode: 2330 state: NSW
# Finished processing suburb: BROKEN HEAD postcode: 2481 state: NSW
# Finished processing suburb: BROKEN HILL postcode: 2880 state: NSW
# Finished processing suburb: BRONTE postcode: 2024 state: NSW
# Finished processing suburb: BROOKFIELD postcode: 2420 state: NSW
# Finished processing suburb: BROOKLET postcode: 2479 state: NSW
# Finished processing suburb: BROOKLYN postcode: 2083 state: NSW
# Finished processing suburb: BROOKVALE postcode: 2100 state: NSW
# Finished processing suburb: BROOMS HEAD postcode: 2463 state: NSW
# Finished processing suburb: BROUGHTON VALE postcode: 2535 state: NSW
# Finished processing suburb: BROUGHTON postcode: 2535 state: NSW
# Finished processing suburb: BROULEE postcode: 2537 state: NSW
# Finished processing suburb: BROWNLOW HILL postcode: 2570 state: NSW
# Finished processing suburb: BROWNS CREEK postcode: 2799 state: NSW
# Finished processing suburb: BROWNS MOUNTAIN postcode: 2540 state: NSW
# Finished processing suburb: BROWNSVILLE postcode: 2530 state: NSW
# Finished processing suburb: BRUCEDALE postcode: 2650 state: NSW
# Finished processing suburb: BRUNGLE postcode: 2722 state: NSW
# Finished processing suburb: BRUNKERVILLE postcode: 2323 state: NSW
# Finished processing suburb: BRUNSWICK HEADS postcode: 2483 state: NSW
# Finished processing suburb: BRUSHGROVE postcode: 2460 state: NSW
# Finished processing suburb: BUCCA WAUKA postcode: 2429 state: NSW
# Finished processing suburb: BUCCA postcode: 2450 state: NSW
# Finished processing suburb: BUCHANAN postcode: 2323 state: NSW
# Finished processing suburb: BUCKAJO postcode: 2550 state: NSW
# Finished processing suburb: BUCKRA BENDINNI postcode: 2449 state: NSW
# Finished processing suburb: BUDGEWOI postcode: 2262 state: NSW
# Finished processing suburb: BUFF POINT postcode: 2262 state: NSW
# Finished processing suburb: BULAHDELAH postcode: 2423 state: NSW
# Finished processing suburb: BULGA postcode: 2330 state: NSW
# Finished processing suburb: BULLA CREEK postcode: 2594 state: NSW
# Finished processing suburb: BULLABURRA postcode: 2784 state: NSW
# Finished processing suburb: BULLAWA CREEK postcode: 2390 state: NSW
# Finished processing suburb: BULLI postcode: 2516 state: NSW
# Finished processing suburb: BULLIO postcode: 2575 state: NSW
# Finished processing suburb: BUMBALDRY postcode: 2794 state: NSW
# Finished processing suburb: BUNDABAH postcode: 2324 state: NSW
# Finished processing suburb: BUNDANOON postcode: 2578 state: NSW
# Finished processing suburb: BUNDARRA postcode: 2359 state: NSW
# Finished processing suburb: BUNDEENA postcode: 2230 state: NSW
# Finished processing suburb: BUNDEWALLAH postcode: 2535 state: NSW
# Finished processing suburb: BUNDOOK postcode: 2422 state: NSW
# Finished processing suburb: BUNGALORA postcode: 2486 state: NSW
# Finished processing suburb: BUNGARRIBEE postcode: 2767 state: NSW
# Finished processing suburb: BUNGAWALBIN postcode: 2469 state: NSW
# Finished processing suburb: BUNGENDORE postcode: 2621 state: NSW
# Finished processing suburb: BUNGONIA postcode: 2580 state: NSW
# Finished processing suburb: BUNGWAHL postcode: 2423 state: NSW
# Finished processing suburb: BUNNALOO postcode: 2731 state: NSW
# Finished processing suburb: BUNNAN postcode: 2337 state: NSW
# Finished processing suburb: BUNYAH postcode: 2429 state: NSW
# Finished processing suburb: BUNYAN postcode: 2630 state: NSW
# Finished processing suburb: BURCHER postcode: 2671 state: NSW
# Finished processing suburb: BURONGA postcode: 2739 state: NSW
# Finished processing suburb: BURRA postcode: 2620 state: NSW
# Finished processing suburb: BURRADOO postcode: 2576 state: NSW
# Finished processing suburb: BURRAGA postcode: 2795 state: NSW
# Finished processing suburb: BURRAGATE postcode: 2550 state: NSW
# Finished processing suburb: BURRANEER postcode: 2230 state: NSW
# Finished processing suburb: BURRAPINE postcode: 2447 state: NSW
# Finished processing suburb: BURRAWANG postcode: 2577 state: NSW
# Finished processing suburb: BURRELL CREEK postcode: 2429 state: NSW
# Finished processing suburb: BURRILL LAKE postcode: 2539 state: NSW
# Finished processing suburb: BURRINGBAR postcode: 2483 state: NSW
# Finished processing suburb: BURRUMBUTTOCK postcode: 2642 state: NSW
# Finished processing suburb: BURWOOD HEIGHTS postcode: 2136 state: NSW
# Finished processing suburb: BURWOOD postcode: 2134 state: NSW
# Finished processing suburb: BUSBY postcode: 2168 state: NSW
# Finished processing suburb: BUTTABA postcode: 2283 state: NSW
# Finished processing suburb: BUTTERWICK postcode: 2321 state: NSW
# Finished processing suburb: BUXTON postcode: 2571 state: NSW
# Finished processing suburb: BYABARRA postcode: 2446 state: NSW
# Finished processing suburb: BYANGUM postcode: 2484 state: NSW
# Finished processing suburb: BYRON BAY postcode: 2481 state: NSW
# Finished processing suburb: BYRRILL CREEK postcode: 2484 state: NSW
# Finished processing suburb: BYWONG postcode: 2621 state: NSW
# Finished processing suburb: CABARITA BEACH postcode: 2488 state: NSW
# Finished processing suburb: CABARITA postcode: 2137 state: NSW
# Finished processing suburb: CABRAMATTA WEST postcode: 2166 state: NSW
# Finished processing suburb: CABRAMATTA postcode: 2166 state: NSW
# Finished processing suburb: CADDENS postcode: 2747 state: NSW
# Finished processing suburb: CAERLEON postcode: 2850 state: NSW
# Finished processing suburb: CALALA postcode: 2340 state: NSW
# Finished processing suburb: CALDERWOOD postcode: 2527 state: NSW
# Finished processing suburb: CALLALA BAY postcode: 2540 state: NSW
# Finished processing suburb: CALLALA BEACH postcode: 2540 state: NSW
# Finished processing suburb: CAMBEWARRA VILLAGE postcode: 2540 state: NSW
# Finished processing suburb: CAMBEWARRA postcode: 2540 state: NSW
# Finished processing suburb: CAMBRA postcode: 2420 state: NSW
# Finished processing suburb: CAMBRIDGE GARDENS postcode: 2747 state: NSW
# Finished processing suburb: CAMBRIDGE PARK postcode: 2747 state: NSW
# Finished processing suburb: CAMDEN HEAD postcode: 2443 state: NSW
# Finished processing suburb: CAMDEN PARK postcode: 2570 state: NSW
# Finished processing suburb: CAMDEN SOUTH postcode: 2570 state: NSW
# Finished processing suburb: CAMDEN postcode: 2570 state: NSW
# Finished processing suburb: CAMERON PARK postcode: 2285 state: NSW
# Finished processing suburb: CAMMERAY postcode: 2062 state: NSW
# Finished processing suburb: CAMP CREEK postcode: 4385 state: NSW
# Finished processing suburb: CAMPBELLTOWN postcode: 2560 state: NSW
# Finished processing suburb: CAMPERDOWN postcode: 2050 state: NSW
# Finished processing suburb: CAMPSIE postcode: 2194 state: NSW
# Finished processing suburb: CAMPVALE postcode: 2318 state: NSW
# Finished processing suburb: CAMS WHARF postcode: 2281 state: NSW
# Finished processing suburb: CANADA BAY postcode: 2046 state: NSW
# Finished processing suburb: CANDELO postcode: 2550 state: NSW
# Finished processing suburb: CANIABA postcode: 2480 state: NSW
# Finished processing suburb: CANLEY HEIGHTS postcode: 2166 state: NSW
# Finished processing suburb: CANLEY VALE postcode: 2166 state: NSW
# Finished processing suburb: CANOBOLAS postcode: 2800 state: NSW
# Finished processing suburb: CANOELANDS postcode: 2157 state: NSW
# Finished processing suburb: CANOWINDRA postcode: 2804 state: NSW
# Finished processing suburb: CANTERBURY postcode: 2193 state: NSW
# Finished processing suburb: CANTON BEACH postcode: 2263 state: NSW
# Finished processing suburb: CANYONLEIGH postcode: 2577 state: NSW
# Finished processing suburb: CAPERTEE postcode: 2846 state: NSW
# Finished processing suburb: CAPTAINS FLAT postcode: 2623 state: NSW
# Finished processing suburb: CARAGABAL postcode: 2810 state: NSW
# Finished processing suburb: CARCOAR postcode: 2791 state: NSW
# Finished processing suburb: CARDIFF HEIGHTS postcode: 2285 state: NSW
# Finished processing suburb: CARDIFF SOUTH postcode: 2285 state: NSW
# Finished processing suburb: CARDIFF postcode: 2285 state: NSW
# Finished processing suburb: CAREY BAY postcode: 2283 state: NSW
# Finished processing suburb: CARGO postcode: 2800 state: NSW
# Finished processing suburb: CARINGBAH SOUTH postcode: 2229 state: NSW
# Finished processing suburb: CARINGBAH postcode: 2229 state: NSW
# Finished processing suburb: CARLAMINDA postcode: 2630 state: NSW
# Finished processing suburb: CARLINGFORD postcode: 2118 state: NSW
# Finished processing suburb: CARLTON postcode: 2218 state: NSW
# Finished processing suburb: CARNES HILL postcode: 2171 state: NSW
# Finished processing suburb: CAROOL postcode: 2486 state: NSW
# Finished processing suburb: CAROONA postcode: 2343 state: NSW
# Finished processing suburb: CARRAMAR postcode: 2163 state: NSW
# Finished processing suburb: CARRINGTON postcode: 2294 state: NSW
# Finished processing suburb: CARRINGTON postcode: 2324 state: NSW
# Finished processing suburb: CARROLL postcode: 2340 state: NSW
# Finished processing suburb: CARRS CREEK postcode: 2460 state: NSW
# Finished processing suburb: CARSS PARK postcode: 2221 state: NSW
# Finished processing suburb: CARTWRIGHT postcode: 2168 state: NSW
# Finished processing suburb: CARTWRIGHTS HILL postcode: 2650 state: NSW
# Finished processing suburb: CARWOOLA postcode: 2620 state: NSW
# Finished processing suburb: CASINO postcode: 2470 state: NSW
# Finished processing suburb: CASSILIS postcode: 2329 state: NSW
# Finished processing suburb: CASTLE COVE postcode: 2069 state: NSW
# Finished processing suburb: CASTLE HILL postcode: 2154 state: NSW
# Finished processing suburb: CASTLECRAG postcode: 2068 state: NSW
# Finished processing suburb: CASTLEREAGH postcode: 2749 state: NSW
# Finished processing suburb: CASUARINA postcode: 2487 state: NSW
# Finished processing suburb: CASULA postcode: 2170 state: NSW
# Finished processing suburb: CATALINA postcode: 2536 state: NSW
# Finished processing suburb: CATHCART postcode: 2632 state: NSW
# Finished processing suburb: CATHERINE FIELD postcode: 2557 state: NSW
# Finished processing suburb: CATHERINE HILL BAY postcode: 2281 state: NSW
# Finished processing suburb: CATTAI postcode: 2756 state: NSW
# Finished processing suburb: CAVES BEACH postcode: 2281 state: NSW
# Finished processing suburb: CAWDOR postcode: 2570 state: NSW
# Finished processing suburb: CAWONGLA postcode: 2474 state: NSW
# Finished processing suburb: CECIL HILLS postcode: 2171 state: NSW
# Finished processing suburb: CECIL PARK postcode: 2178 state: NSW
# Finished processing suburb: CEDAR PARTY postcode: 2429 state: NSW
# Finished processing suburb: CEDAR POINT postcode: 2474 state: NSW
# Finished processing suburb: CENTENNIAL PARK postcode: 2021 state: NSW
# Finished processing suburb: CENTRAL MACDONALD postcode: 2775 state: NSW
# Finished processing suburb: CENTRAL TILBA postcode: 2546 state: NSW
# Finished processing suburb: CESSNOCK postcode: 2325 state: NSW
# Finished processing suburb: CHAIN VALLEY BAY postcode: 2259 state: NSW
# Finished processing suburb: CHARBON postcode: 2848 state: NSW
# Finished processing suburb: CHARLESTOWN postcode: 2290 state: NSW
# Finished processing suburb: CHARLOTTE BAY postcode: 2428 state: NSW
# Finished processing suburb: CHARMHAVEN postcode: 2263 state: NSW
# Finished processing suburb: CHATHAM VALLEY postcode: 2787 state: NSW
# Finished processing suburb: CHATSWOOD WEST postcode: 2067 state: NSW
# Finished processing suburb: CHATSWOOD postcode: 2067 state: NSW
# Finished processing suburb: CHATSWORTH postcode: 2469 state: NSW
# Finished processing suburb: CHEERO POINT postcode: 2083 state: NSW
# Finished processing suburb: CHELTENHAM postcode: 2119 state: NSW
# Finished processing suburb: CHERRYBROOK postcode: 2126 state: NSW
# Finished processing suburb: CHESTER HILL postcode: 2162 state: NSW
# Finished processing suburb: CHIFLEY postcode: 2036 state: NSW
# Finished processing suburb: CHILCOTTS GRASS postcode: 2480 state: NSW
# Finished processing suburb: CHILLINGHAM postcode: 2484 state: NSW
# Finished processing suburb: CHINDERAH postcode: 2487 state: NSW
# Finished processing suburb: CHIPPENDALE postcode: 2008 state: NSW
# Finished processing suburb: CHIPPING NORTON postcode: 2170 state: NSW
# Finished processing suburb: CHISHOLM postcode: 2322 state: NSW
# Finished processing suburb: CHISWICK postcode: 2046 state: NSW
# Finished processing suburb: CHITTAWAY BAY postcode: 2261 state: NSW
# Finished processing suburb: CHITTAWAY POINT postcode: 2261 state: NSW
# Finished processing suburb: CHULLORA postcode: 2190 state: NSW
# Finished processing suburb: CHURCH POINT postcode: 2105 state: NSW
# Finished processing suburb: CLANDULLA postcode: 2848 state: NSW
# Finished processing suburb: CLAREMONT MEADOWS postcode: 2747 state: NSW
# Finished processing suburb: CLARENCE TOWN postcode: 2321 state: NSW
# Finished processing suburb: CLARENCE postcode: 2790 state: NSW
# Finished processing suburb: CLARENDON postcode: 2756 state: NSW
# Finished processing suburb: CLARENZA postcode: 2460 state: NSW
# Finished processing suburb: CLAREVILLE postcode: 2107 state: NSW
# Finished processing suburb: CLAYMORE postcode: 2559 state: NSW
# Finished processing suburb: CLEAR CREEK postcode: 2795 state: NSW
# Finished processing suburb: CLEAR RANGE postcode: 2620 state: NSW
# Finished processing suburb: CLEMTON PARK postcode: 2206 state: NSW
# Finished processing suburb: CLIFTLEIGH postcode: 2321 state: NSW
# Finished processing suburb: CLIFTON GROVE postcode: 2800 state: NSW
# Finished processing suburb: CLIFTON postcode: 2515 state: NSW
# Finished processing suburb: CLONTARF postcode: 2093 state: NSW
# Finished processing suburb: CLOTHIERS CREEK postcode: 2484 state: NSW
# Finished processing suburb: CLOVASS postcode: 2480 state: NSW
# Finished processing suburb: CLOVELLY postcode: 2031 state: NSW
# Finished processing suburb: CLUNES postcode: 2480 state: NSW
# Finished processing suburb: CLYBUCCA postcode: 2440 state: NSW
# Finished processing suburb: CLYDESDALE postcode: 2330 state: NSW
# Finished processing suburb: COAL POINT postcode: 2283 state: NSW
# Finished processing suburb: COALCLIFF postcode: 2508 state: NSW
# Finished processing suburb: COASTERS RETREAT postcode: 2108 state: NSW
# Finished processing suburb: COBAKI LAKES postcode: 2486 state: NSW
# Finished processing suburb: COBAKI postcode: 2486 state: NSW
# Finished processing suburb: COBAR postcode: 2835 state: NSW
# Finished processing suburb: COBARGO postcode: 2550 state: NSW
# Finished processing suburb: COBBITTY postcode: 2570 state: NSW
# Finished processing suburb: CODRINGTON postcode: 2471 state: NSW
# Finished processing suburb: COFFEE CAMP postcode: 2480 state: NSW
# Finished processing suburb: COFFS HARBOUR JETTY postcode: 2450 state: NSW
# Finished processing suburb: COFFS HARBOUR postcode: 2450 state: NSW
# Finished processing suburb: COGRA BAY postcode: 2083 state: NSW
# Finished processing suburb: COILA postcode: 2537 state: NSW
# Finished processing suburb: COLDSTREAM postcode: 2462 state: NSW
# Finished processing suburb: COLEAMBALLY postcode: 2707 state: NSW
# Finished processing suburb: COLEBEE postcode: 2761 state: NSW
# Finished processing suburb: COLEDALE postcode: 2515 state: NSW
# Finished processing suburb: COLINTON postcode: 2626 state: NSW
# Finished processing suburb: COLLAROY BEACH postcode: 2097 state: NSW
# Finished processing suburb: COLLAROY PLATEAU postcode: 2097 state: NSW
# Finished processing suburb: COLLAROY postcode: 2097 state: NSW
# Finished processing suburb: COLLECTOR postcode: 2581 state: NSW
# Finished processing suburb: COLLIE postcode: 2827 state: NSW
# Finished processing suburb: COLLINGULLIE postcode: 2650 state: NSW
# Finished processing suburb: COLLINS CREEK postcode: 2474 state: NSW
# Finished processing suburb: COLLOMBATTI postcode: 2440 state: NSW
# Finished processing suburb: COLO HEIGHTS postcode: 2756 state: NSW
# Finished processing suburb: COLO VALE postcode: 2575 state: NSW
# Finished processing suburb: COLO postcode: 2756 state: NSW
# Finished processing suburb: COLYTON postcode: 2760 state: NSW
# Finished processing suburb: COMBOYNE postcode: 2429 state: NSW
# Finished processing suburb: COMERONG ISLAND postcode: 2540 state: NSW
# Finished processing suburb: COMMISSIONERS CREEK postcode: 2484 state: NSW
# Finished processing suburb: COMO WEST postcode: 2226 state: NSW
# Finished processing suburb: COMO postcode: 2226 state: NSW
# Finished processing suburb: CONARGO postcode: 2710 state: NSW
# Finished processing suburb: CONCORD WEST postcode: 2138 state: NSW
# Finished processing suburb: CONCORD postcode: 2137 state: NSW
# Finished processing suburb: CONDELL PARK postcode: 2200 state: NSW
# Finished processing suburb: CONDOBOLIN postcode: 2877 state: NSW
# Finished processing suburb: CONDONG postcode: 2484 state: NSW
# Finished processing suburb: CONGARINNI NORTH postcode: 2447 state: NSW
# Finished processing suburb: CONGARINNI postcode: 2447 state: NSW
# ...
# Finished processing suburb: OAKFORD postcode: 6121 state: WA
# Finished processing suburb: OCEAN BEACH postcode: 6333 state: WA
# Finished processing suburb: OCEAN REEF postcode: 6027 state: WA
# Finished processing suburb: OLDBURY postcode: 6121 state: WA
# Finished processing suburb: ONGERUP postcode: 6336 state: WA
# Finished processing suburb: ONSLOW postcode: 6710 state: WA
# Finished processing suburb: ORANA postcode: 6330 state: WA
# Finished processing suburb: ORANGE GROVE postcode: 6109 state: WA
# Finished processing suburb: ORELIA postcode: 6167 state: WA
# Finished processing suburb: OSBORNE PARK postcode: 6017 state: WA
# Finished processing suburb: PADBURY postcode: 6025 state: WA
# Finished processing suburb: PALGARUP postcode: 6258 state: WA
# Finished processing suburb: PALMYRA postcode: 6157 state: WA
# Finished processing suburb: PARABURDOO postcode: 6754 state: WA
# Finished processing suburb: PARKERVILLE postcode: 6081 state: WA
# Finished processing suburb: PARKFIELD postcode: 6233 state: WA
# Finished processing suburb: PARKLANDS postcode: 6180 state: WA
# Finished processing suburb: PARKWOOD postcode: 6147 state: WA
# Finished processing suburb: PARMELIA postcode: 6167 state: WA
# Finished processing suburb: PAULLS VALLEY postcode: 6076 state: WA
# Finished processing suburb: PAYNEDALE postcode: 6239 state: WA
# Finished processing suburb: PEACEFUL BAY postcode: 6333 state: WA
# Finished processing suburb: PEARSALL postcode: 6065 state: WA
# Finished processing suburb: PEGS CREEK postcode: 6714 state: WA
# Finished processing suburb: PELICAN POINT postcode: 6230 state: WA
# Finished processing suburb: PEMBERTON postcode: 6260 state: WA
# Finished processing suburb: PEPPERMINT GROVE BEACH postcode: 6271 state: WA
# Finished processing suburb: PEPPERMINT GROVE postcode: 6011 state: WA
# Finished processing suburb: PERENJORI postcode: 6620 state: WA
# Finished processing suburb: PERTH postcode: 6000 state: WA
# Finished processing suburb: PIARA WATERS postcode: 6112 state: WA
# Finished processing suburb: PICCADILLY postcode: 6430 state: WA
# Finished processing suburb: PICKERING BROOK postcode: 6076 state: WA
# Finished processing suburb: PICTON EAST postcode: 6229 state: WA
# Finished processing suburb: PICTON postcode: 6229 state: WA
# Finished processing suburb: PIESSE BROOK postcode: 6076 state: WA
# Finished processing suburb: PINGELLY postcode: 6308 state: WA
# Finished processing suburb: PINJAR postcode: 6078 state: WA
# Finished processing suburb: PINJARRA postcode: 6208 state: WA
# Finished processing suburb: PINK LAKE postcode: 6450 state: WA
# Finished processing suburb: POINT SAMSON postcode: 6720 state: WA
# Finished processing suburb: POPANYINNING postcode: 6309 state: WA
# Finished processing suburb: PORONGURUP postcode: 6324 state: WA
# Finished processing suburb: PORT ALBANY postcode: 6330 state: WA
# Finished processing suburb: PORT DENISON postcode: 6525 state: WA
# Finished processing suburb: PORT HEDLAND postcode: 6721 state: WA
# Finished processing suburb: PORT KENNEDY postcode: 6172 state: WA
# Finished processing suburb: PRESTON BEACH postcode: 6215 state: WA
# Finished processing suburb: PRESTON SETTLEMENT postcode: 6225 state: WA
# Finished processing suburb: PREVELLY postcode: 6285 state: WA
# Finished processing suburb: QUAIRADING postcode: 6383 state: WA
# Finished processing suburb: QUEDJINUP postcode: 6281 state: WA
# Finished processing suburb: QUEENS PARK postcode: 6107 state: WA
# Finished processing suburb: QUINDALUP postcode: 6281 state: WA
# Finished processing suburb: QUINNINUP postcode: 6258 state: WA
# Finished processing suburb: QUINNS ROCKS postcode: 6030 state: WA
# Finished processing suburb: RANGEWAY postcode: 6530 state: WA
# Finished processing suburb: RAVENSTHORPE postcode: 6346 state: WA
# Finished processing suburb: RAVENSWOOD postcode: 6208 state: WA
# Finished processing suburb: REDBANK postcode: 6721 state: WA
# Finished processing suburb: REDCLIFFE postcode: 6104 state: WA
# Finished processing suburb: REDGATE postcode: 6286 state: WA
# Finished processing suburb: REDMOND postcode: 6327 state: WA
# Finished processing suburb: REINSCOURT postcode: 6280 state: WA
# Finished processing suburb: RIDGEWOOD postcode: 6030 state: WA
# Finished processing suburb: RIVERTON postcode: 6148 state: WA
# Finished processing suburb: RIVERVALE postcode: 6103 state: WA
# Finished processing suburb: ROBINSON postcode: 6330 state: WA
# Finished processing suburb: ROCKINGHAM postcode: 6168 state: WA
# Finished processing suburb: ROCKY GULLY postcode: 6397 state: WA
# Finished processing suburb: ROEBOURNE postcode: 6718 state: WA
# Finished processing suburb: ROEBUCK postcode: 6725 state: WA
# Finished processing suburb: ROELANDS postcode: 6226 state: WA
# Finished processing suburb: ROLEYSTONE postcode: 6111 state: WA
# Finished processing suburb: ROSSMOYNE postcode: 6148 state: WA
# Finished processing suburb: RUDDS GULLY postcode: 6532 state: WA
# Finished processing suburb: SABINA RIVER postcode: 6280 state: WA
# Finished processing suburb: SAFETY BAY postcode: 6169 state: WA
# Finished processing suburb: SALTER POINT postcode: 6152 state: WA
# Finished processing suburb: SAMSON postcode: 6163 state: WA
# Finished processing suburb: SAN REMO postcode: 6210 state: WA
# Finished processing suburb: SANDSTONE postcode: 6639 state: WA
# Finished processing suburb: SAWYERS VALLEY postcode: 6074 state: WA
# Finished processing suburb: SCARBOROUGH postcode: 6019 state: WA
# Finished processing suburb: SEABIRD postcode: 6042 state: WA
# Finished processing suburb: SECRET HARBOUR postcode: 6173 state: WA
# Finished processing suburb: SEPPINGS postcode: 6330 state: WA
# Finished processing suburb: SERPENTINE postcode: 6125 state: WA
# Finished processing suburb: SEVILLE GROVE postcode: 6112 state: WA
# Finished processing suburb: SHADFORTH postcode: 6333 state: WA
# Finished processing suburb: SHELLEY postcode: 6148 state: WA
# Finished processing suburb: SHENTON PARK postcode: 6008 state: WA
# Finished processing suburb: SHOALWATER postcode: 6169 state: WA
# Finished processing suburb: SIESTA PARK postcode: 6280 state: WA
# Finished processing suburb: SILVER SANDS postcode: 6210 state: WA
# Finished processing suburb: SINAGRA postcode: 6065 state: WA
# Finished processing suburb: SINCLAIR postcode: 6450 state: WA
# Finished processing suburb: SINGLETON postcode: 6175 state: WA
# Finished processing suburb: SOMERVILLE postcode: 6430 state: WA
# Finished processing suburb: SORRENTO postcode: 6020 state: WA
# Finished processing suburb: SOUTH BOULDER postcode: 6432 state: WA
# Finished processing suburb: SOUTH BUNBURY postcode: 6230 state: WA
# Finished processing suburb: SOUTH CARNARVON postcode: 6701 state: WA
# Finished processing suburb: SOUTH FREMANTLE postcode: 6162 state: WA
# Finished processing suburb: SOUTH GUILDFORD postcode: 6055 state: WA
# Finished processing suburb: SOUTH HEDLAND postcode: 6722 state: WA
# Finished processing suburb: SOUTH KALGOORLIE postcode: 6430 state: WA
# Finished processing suburb: SOUTH LAKE postcode: 6164 state: WA
# Finished processing suburb: SOUTH PERTH postcode: 6151 state: WA
# Finished processing suburb: SOUTH YUNDERUP postcode: 6208 state: WA
# Finished processing suburb: SOUTHAMPTON postcode: 6253 state: WA
# Finished processing suburb: SOUTHERN CROSS postcode: 6426 state: WA
# Finished processing suburb: SOUTHERN RIVER postcode: 6110 state: WA
# Finished processing suburb: SPALDING postcode: 6530 state: WA
# Finished processing suburb: SPEARWOOD postcode: 6163 state: WA
# Finished processing suburb: SPENCER PARK postcode: 6330 state: WA
# Finished processing suburb: SPENCERS BROOK postcode: 6401 state: WA
# Finished processing suburb: SPRINGFIELD postcode: 6525 state: WA
# Finished processing suburb: ST JAMES postcode: 6102 state: WA
# Finished processing suburb: STAKE HILL postcode: 6181 state: WA
# Finished processing suburb: STIRLING ESTATE postcode: 6271 state: WA
# Finished processing suburb: STIRLING postcode: 6021 state: WA
# Finished processing suburb: STONEVILLE postcode: 6081 state: WA
# Finished processing suburb: STOVE HILL postcode: 6714 state: WA
# Finished processing suburb: STRATHAM postcode: 6237 state: WA
# Finished processing suburb: STRATTON postcode: 6056 state: WA
# Finished processing suburb: SUBIACO postcode: 6008 state: WA
# Finished processing suburb: SUCCESS postcode: 6164 state: WA
# Finished processing suburb: SUNSET BEACH postcode: 6530 state: WA
# Finished processing suburb: SWAN VIEW postcode: 6056 state: WA
# Finished processing suburb: SWANBOURNE postcode: 6010 state: WA
# Finished processing suburb: TAKALARUP postcode: 6324 state: WA
# Finished processing suburb: TAMBELLUP postcode: 6320 state: WA
# Finished processing suburb: TAMMIN postcode: 6409 state: WA
# Finished processing suburb: TAPPING postcode: 6065 state: WA
# Finished processing suburb: TARCOOLA BEACH postcode: 6530 state: WA
# Finished processing suburb: TENTERDEN postcode: 6322 state: WA
# Finished processing suburb: THE LAKES postcode: 6556 state: WA
# Finished processing suburb: THE VINES postcode: 6069 state: WA
# Finished processing suburb: THOMSON BROOK postcode: 6239 state: WA
# Finished processing suburb: THORNLIE postcode: 6108 state: WA
# Finished processing suburb: THREE SPRINGS postcode: 6519 state: WA
# Finished processing suburb: TOM PRICE postcode: 6751 state: WA
# Finished processing suburb: TOODYAY postcode: 6566 state: WA
# Finished processing suburb: TORBAY postcode: 6330 state: WA
# Finished processing suburb: TREEBY postcode: 6164 state: WA
# Finished processing suburb: TRIGG postcode: 6029 state: WA
# Finished processing suburb: TUART HILL postcode: 6060 state: WA
# Finished processing suburb: TWO ROCKS postcode: 6037 state: WA
# Finished processing suburb: UDUC postcode: 6220 state: WA
# Finished processing suburb: UPPER CAPEL postcode: 6239 state: WA
# Finished processing suburb: UPPER SWAN postcode: 6069 state: WA
# Finished processing suburb: USHER postcode: 6230 state: WA
# Finished processing suburb: UTAKARRA postcode: 6530 state: WA
# Finished processing suburb: VASSE postcode: 6280 state: WA
# Finished processing suburb: VICTORIA PARK postcode: 6100 state: WA
# Finished processing suburb: VICTORY HEIGHTS postcode: 6432 state: WA
# Finished processing suburb: VIVEASH postcode: 6056 state: WA
# Finished processing suburb: WAGIN postcode: 6315 state: WA
# Finished processing suburb: WAIKIKI postcode: 6169 state: WA
# Finished processing suburb: WALKAWAY postcode: 6528 state: WA
# Finished processing suburb: WALLISTON postcode: 6076 state: WA
# Finished processing suburb: WALMSLEY postcode: 6330 state: WA
# Finished processing suburb: WALPOLE postcode: 6398 state: WA
# Finished processing suburb: WALSALL postcode: 6280 state: WA
# Finished processing suburb: WANDERING postcode: 6308 state: WA
# Finished processing suburb: WANDI postcode: 6167 state: WA
# Finished processing suburb: WANDINA postcode: 6530 state: WA
# Finished processing suburb: WANERIE postcode: 6503 state: WA
# Finished processing suburb: WANNAMAL postcode: 6505 state: WA
# Finished processing suburb: WANNANUP postcode: 6210 state: WA
# Finished processing suburb: WANNEROO postcode: 6065 state: WA
# Finished processing suburb: WARAWARRUP postcode: 6220 state: WA
# Finished processing suburb: WARNBRO postcode: 6169 state: WA
# Finished processing suburb: WAROONA postcode: 6215 state: WA
# Finished processing suburb: WARRENUP postcode: 6330 state: WA
# Finished processing suburb: WARWICK postcode: 6024 state: WA
# Finished processing suburb: WATERBANK postcode: 6725 state: WA
# Finished processing suburb: WATERFORD postcode: 6152 state: WA
# Finished processing suburb: WATERMANS BAY postcode: 6020 state: WA
# Finished processing suburb: WATHEROO postcode: 6513 state: WA
# Finished processing suburb: WATTLE GROVE postcode: 6107 state: WA
# Finished processing suburb: WATTLEUP postcode: 6166 state: WA
# Finished processing suburb: WELLARD postcode: 6170 state: WA
# Finished processing suburb: WELLINGTON MILL postcode: 6236 state: WA
# Finished processing suburb: WEMBLEY DOWNS postcode: 6019 state: WA
# Finished processing suburb: WEMBLEY postcode: 6014 state: WA
# Finished processing suburb: WEST BEACH postcode: 6450 state: WA
# Finished processing suburb: WEST BUSSELTON postcode: 6280 state: WA
# Finished processing suburb: WEST COOLUP postcode: 6214 state: WA
# Finished processing suburb: WEST END postcode: 6530 state: WA
# Finished processing suburb: WEST LAMINGTON postcode: 6430 state: WA
# Finished processing suburb: WEST LEEDERVILLE postcode: 6007 state: WA
# Finished processing suburb: WEST PERTH postcode: 6005 state: WA
# Finished processing suburb: WEST PINJARRA postcode: 6208 state: WA
# Finished processing suburb: WEST SWAN postcode: 6055 state: WA
# Finished processing suburb: WEST TOODYAY postcode: 6566 state: WA
# Finished processing suburb: WESTMINSTER postcode: 6061 state: WA
# Finished processing suburb: WESTONIA postcode: 6423 state: WA
# Finished processing suburb: WHITBY postcode: 6123 state: WA
# Finished processing suburb: WHITE GUM VALLEY postcode: 6162 state: WA
# Finished processing suburb: WHITE PEAK postcode: 6532 state: WA
# Finished processing suburb: WICKEPIN postcode: 6370 state: WA
# Finished processing suburb: WICKHAM postcode: 6720 state: WA
# Finished processing suburb: WILBINGA postcode: 6041 state: WA
# Finished processing suburb: WILGA postcode: 6243 state: WA
# Finished processing suburb: WILLAGEE postcode: 6156 state: WA
# Finished processing suburb: WILLETTON postcode: 6155 state: WA
# Finished processing suburb: WILLIAMS postcode: 6391 state: WA
# Finished processing suburb: WILLIAMSTOWN postcode: 6430 state: WA
# Finished processing suburb: WILLYUNG postcode: 6330 state: WA
# Finished processing suburb: WILSON postcode: 6107 state: WA
# Finished processing suburb: WILYABRUP postcode: 6280 state: WA
# Finished processing suburb: WINDY HARBOUR postcode: 6262 state: WA
# Finished processing suburb: WINNEJUP postcode: 6255 state: WA
# Finished processing suburb: WINTHROP postcode: 6150 state: WA
# Finished processing suburb: WITCHCLIFFE postcode: 6286 state: WA
# Finished processing suburb: WITHERS postcode: 6230 state: WA
# Finished processing suburb: WOKALUP postcode: 6221 state: WA
# Finished processing suburb: WOMARDEN postcode: 6519 state: WA
# Finished processing suburb: WONGAN HILLS postcode: 6603 state: WA
# Finished processing suburb: WONNERUP postcode: 6280 state: WA
# Finished processing suburb: WONTHELLA postcode: 6530 state: WA
# Finished processing suburb: WOODANILLING postcode: 6316 state: WA
# Finished processing suburb: WOODBRIDGE postcode: 6056 state: WA
# Finished processing suburb: WOODLANDS postcode: 6018 state: WA
# Finished processing suburb: WOODRIDGE postcode: 6041 state: WA
# Finished processing suburb: WOODVALE postcode: 6026 state: WA
# Finished processing suburb: WOOROLOO postcode: 6558 state: WA
# Finished processing suburb: WORSLEY postcode: 6225 state: WA
# Finished processing suburb: WUNDOWIE postcode: 6560 state: WA
# Finished processing suburb: WUNGONG postcode: 6112 state: WA
# Finished processing suburb: WYALKATCHEM postcode: 6485 state: WA
# Finished processing suburb: WYNDHAM postcode: 6740 state: WA
# Finished processing suburb: YABBERUP postcode: 6239 state: WA
# Finished processing suburb: YAKAMIA postcode: 6330 state: WA
# Finished processing suburb: YALLINGUP SIDING postcode: 6282 state: WA
# Finished processing suburb: YALLINGUP postcode: 6282 state: WA
# Finished processing suburb: YALYALUP postcode: 6280 state: WA
# Finished processing suburb: YANCHEP postcode: 6035 state: WA
# Finished processing suburb: YANGEBUP postcode: 6164 state: WA
# Finished processing suburb: YARDARINO postcode: 6525 state: WA
# Finished processing suburb: YARLOOP postcode: 6218 state: WA
# Finished processing suburb: YEALERING postcode: 6372 state: WA
# Finished processing suburb: YERECOIN postcode: 6571 state: WA
# Finished processing suburb: YILLIMINNING postcode: 6312 state: WA
# Finished processing suburb: YOKINE postcode: 6060 state: WA
# Finished processing suburb: YORK postcode: 6302 state: WA
# Finished processing suburb: YORNUP postcode: 6256 state: WA
# Finished processing suburb: YOUNGS SIDING postcode: 6330 state: WA
# Finished processing suburb: YUNA postcode: 6532 state: WA

# %%
#count total rows in suburb_data_df
suburb_data_df.shape[0]
# Out:
# 25544

# %%
batch_size = 1000
num_batches = len(suburb_data_df) // batch_size + 1

for batch in range(num_batches):
    start_index = batch * batch_size
    end_index = min((batch + 1) * batch_size, len(suburb_data_df))
    batch_data = suburb_data_json[start_index:end_index]

    # Send batch_data using requests.post()
    r = requests.post(url, json=suburb_data_json)

    if r.status_code == 200:
        print(f'Suburb data batch {batch+1}/{num_batches} migrated successfully')
    else:
        print(f'Error in migrating suburb data batch {batch+1}/{num_batches}: {r.status_code} {r.reason}')
    
    break
# Out:
# Error in migrating suburb data batch 1/26: 500 Internal Server Error

# %%
batch_data_json[:1]
# Out:
# [{'state': 'ACT',
#   'suburb': 'ACTON',
#   'postcode': '2601',
#   'beds': 2,
#   'propertyType': 'Unit',
#   'medianPrice': None,
#   'medianRent': None,
#   'avgDaysOnMarket': None,
#   'soldThisYear': 1,
#   'entryLevelPrice': None,
#   'luxuryLevelPrice': None,
#   'annualGrowth': None,
#   'rentalYield': None,
#   'totalYield': None,
#   'remoteness': 'Major Cities of Australia',
#   'remoteness_code': '0'}]
